# %%
import sys
src_dir = '/Users/palmerio/Science_projects/GRB_population_model/grbpop/'
sys.path.insert(0, src_dir)

# GRB pop module imports
from GRB_population import GRBPopulation
import physics as ph
import stats as st
import io_grb_pop as io
from io_grb_pop import root_dir
import miscellaneous as msc
import plotting_functions as pf
from cosmology import init_cosmology
from ECLAIRs import init_ECLAIRs
import cosmology as cs
import f90_functions as f90f

# General imports
import yaml
import logging
import corner
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path

log = logging.getLogger(__name__)
logging.basicConfig(stream=sys.stdout, level=logging.INFO,
                    format='%(asctime)s.%(msecs)03d [%(levelname)s] %(message)s',
                    datefmt='%H:%M:%S')
logging.getLogger('matplotlib').setLevel(logging.WARNING)
plt.style.use('paper')
colors = ['#225ea8', '#41b6c4', '#d94801', '#fd8d3c']
Nb_GRBs_glob = int(1e6)
save_fig = True

# %%
def compare_pop(config, samples, instruments, obs_constraints, cosmo, params, run_mode=None, nGRB0=None,
                plot_obs=True, color=None, lab=None, fig_cstr=None, save_fig=False, verbose=False):
    config['samples'] = ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
    incl_samples, incl_instruments, incl_constraints = io.create_config(config=config,
                                                           samples=samples,
                                                           instruments=instruments,
                                                           obs_constraints=obs_constraints)

    gp = GRBPopulation(Nb_GRBs=Nb_GRBs_glob)
    gp.draw_GRB_properties(cosmo, params, run_mode=run_mode)
    gp.calc_peak_photon_flux(incl_instruments)
    gp.calc_peak_energy_flux(incl_instruments)
    gp.calc_photon_fluence(incl_instruments)
    gp.calc_energy_fluence(incl_instruments)
    gp.calc_det_prob(incl_samples)
    gp.create_mock_constraints()
    gp.compare_to_observational_constraints(constraints=incl_constraints)
    if nGRB0 is None:
        gp.normalize_to_Stern()
    else:
        gp.normalize_from(nGRB0=nGRB0)
    if verbose:
        gp.summary()

    # Observational constraints
    plt.style.use('presentation')
    if fig_cstr is None:
        fig, axes = plt.subplots(1,3, figsize=(15,4), tight_layout=False)
    else:
        fig = fig_cstr
        axes = fig.axes
    pf.plot_intensity_constraint(axes[0], pop=gp, label=lab, color=color, plot_obs=plot_obs)
    pf.plot_spectral_constraint(axes[1], pop=gp, label=lab, color=color, plot_obs=plot_obs)
    pf.plot_redshift_constraint(axes[2], pop=gp, label=lab, color=color, plot_obs=plot_obs)
    axes[2].hist(gp.properties['z'], color=color, linewidth=1, bins=np.linspace(0,6,31),
                 ls='--', alpha=0.8, density=True, histtype='step', zorder=10)
    axes[0].legend(loc='lower left')

    if save_fig:
        fig.savefig(f'/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/constraints_{lab}.pdf', bbox_inches='tight')

    return gp, fig

def compare_SHOALS(pop, color, lab, plot_obs=True, fig=None, save_fig=False):
    # SHOALS redshift distribution
    plt.style.use('paper')
    if fig is None:
        fig, ax = plt.subplots(figsize=(8,6))
    else:
        ax = fig.axes[0]

    if plot_obs:
        pf.plot_SHOALS_z_distr_with_bounds(ax)

    df = pop.properties
    x, y = st.unbinned_empirical_cdf(df['z'])
    ax.plot(x, y, color=color, linewidth=2, ls='--', alpha=0.8)
    pf.plot_SHOALS_distr(pop,
                          key='z',
                          plot_obs=False,
                          cumul=True,
                          ax=ax,
                          mod_color=color,
                          mod_label=lab, linewidth=3)

    if save_fig:
        fig.savefig(f'/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/SHOALS_z_distr_{lab}.pdf', bbox_inches='tight')
    return fig

def compare_EpL_plane(pop, lab, color, save_fig=False):
    plt.style.use('paper')
    df = pop.properties
    cond = df['pht_pflx_BAT'] >= 2.6
    fig, axes = pf.cool_hist2d(np.log10(df['L'].to_numpy()), np.log10(df['Ep'].to_numpy()),
                   mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False,
                   plot_left_hist=False, plot_top_hist=False,
                   hist2d_kwargs={'color':'gray', 'bins':30,
                                  'contour_kwargs':{'linewidths':1.5, 'zorder':2},
                                  'plot_datapoints':False, 
                                  'plot_density':False, 
                                  'plot_contours':True,
                                  'fill_contours':False})
    pf.cool_hist2d(np.log10(df[cond]['L'].to_numpy()), np.log10(df[cond]['Ep'].to_numpy()), fig=fig,
                   mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False,
                   left_hist_kwargs={'label': None,
                                     'bins':np.linspace(1,4,31),
                                     'edgecolor':color,
                                     'linewidth':3,
                                     'zorder':5,
                                     'alpha':0.9,
                                     'histtype':'step'},
                   top_hist_kwargs={'label': None,
                                    'bins': np.linspace(49,55,31),
                                    'edgecolor': color,
                                    'linewidth':3,
                                    'zorder':5,
                                    'alpha':0.9,
                                    'histtype':'step'},
                   hist2d_kwargs={'color':color, 
                                  'contour_kwargs':{'linewidths':1},
                                  'plot_datapoints':False, 
                                  'plot_density':False, 
                                  'plot_contours':True,
                                  'fill_contours':True})
    pf.plot_eBAT6_EpL(axes=axes, mini_cax=False, show_relation=False)
    if save_fig:
        fig.savefig(f'/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/eBAT6_EpL_{lab}.pdf', bbox_inches='tight')

    return

# %%
# Wanderman & Piran 2010
WP10 = True
nGRB0 = 1.3e-9 # yr-1 Mpc-3
nGRB0_err = 0.65e-9 # yr-1 Mpc-3
if WP10:
    color='C0'
    lab = 'WP10'
    paths_to_dir, paths_to_files = io.generate_paths()
    config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
    # Cosmology is slightly different (h=0.7 instead of 0.71)
    cosmo = cs.create_cosmology(OmegaM=0.27, OmegaL=0.73, h=0.7, zmax=100)
    params['luminosity_function']={'model':'EBPL',
                                  'logLbreak':52.5,
                                  'slopeL':1.17,
                                  'slopeH':2.44,
                                  'logLmin':50,
                                  'logLmax':54,
                                  'k_evol':0}
    params['redshift_distribution']={'model':'BPL',
                                    'zm':3.11,
                                    'a':2.07,
                                    'b':-1.36}
    params['peak_energy_distribution']={'model':'Fixed',
                                    'Ep0':511.}
    params['spectral_shape']={'model':'Fixed',
                              'shape':'Band',
                              'alpha':1,
                              'beta':2.25}
gp, f = compare_pop(config, samples, instruments, obs_constraints, cosmo, params,
                color=color, lab=lab, fig_cstr=None, save_fig=True)
compare_SHOALS(gp, lab=lab, color=color, save_fig=True)

plt.show()
# Out:
# 15:52:19.661 [INFO] Creating cosmology with: OmegaM = 0.27, OmegaL = 0.73, H0 = 70.0
# 15:52:20.499 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 15:52:20.501 [INFO] Including instruments: ['BATSE', 'BAT']
# 15:52:20.502 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 15:52:20.956 [INFO] Starting calculations of peak photon fluxes...
# 15:52:32.797 [INFO] Starting calculations of peak photon fluxes...
# 15:52:44.028 [INFO] Starting calculations of peak energy fluxes...
# 15:53:03.793 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# 15:53:08.098 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 15:53:08.106 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 15:53:08.127 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 15:53:08.165 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 15:53:09.607 [INFO] In compute_CDF_bounds_by_MC: plotting...

# %%
# Pescalli 2016
P16 = True
nGRB0 = 4e-10 # yr-1 Mpc-3
nGRB0_err = 1e-10 # yr-1 Mpc-3
if P16:
    lab = 'P16'
    color = 'teal'
    paths_to_dir, paths_to_files = io.generate_paths()
    config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
    # Cosmology is slightly different
    cosmo = cs.create_cosmology(OmegaM=0.3, OmegaL=0.7, h=0.7, zmax=100)
    params['luminosity_function']={'model':'EBPL',
                                  'logLbreak':51.45,
                                  'slopeL':1.32,
                                  'slopeH':1.84,
                                  'logLmin':49,
                                  'logLmax':54,
                                  'k_evol':2.5}
    params['redshift_distribution']={'model':'MD14',
                                     'a':0.015,
                                     'b':2.7,
                                     'c':2.9,
                                     'd':5.6}
    params['peak_energy_distribution']={'model':'A',
                                        'Ep0':309.,
                                        'alpha_amati':0.54,
                                        'sigmaEp':0.28,
                                        'L0':1.6e52}
    params['spectral_shape']={'model':'Fixed',
                              'shape':'Band',
                              'alpha':1,
                              'beta':2.25}

    gp, f = compare_pop(config, samples, instruments, obs_constraints, cosmo, params, nGRB0=nGRB0,
                    color=color, lab=lab, fig_cstr=None, save_fig=True)

    compare_SHOALS(gp, lab=lab, color=color, save_fig=True)
    compare_EpL_plane(gp, lab=lab, color=color, save_fig=True)

    plt.show()
# Out:
# 15:53:10.982 [INFO] Creating cosmology with: OmegaM = 0.3, OmegaL = 0.7, H0 = 70.0
# 15:53:11.838 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 15:53:11.839 [INFO] Including instruments: ['BATSE', 'BAT']
# 15:53:11.840 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 15:53:12.358 [INFO] Starting calculations of peak photon fluxes...
# 15:53:23.854 [INFO] Starting calculations of peak photon fluxes...
# 15:53:35.158 [INFO] Starting calculations of peak energy fluxes...
# 15:53:55.122 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# 15:53:56.955 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 15:53:56.958 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 15:53:56.980 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 15:53:57.007 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 15:53:58.467 [INFO] In compute_CDF_bounds_by_MC: plotting...
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)

# %%
# Salvaterra 2012
S12 = True

Zth_s = [0.1, 1., 1.]
n_dens_s = [None, 1.7, None]
k_evol_s = [0.0, 0.0, 2.1]
slopeL_s = [1.45, 1.50, 0.74]
slopeH_s = [2.58, 2.32, 1.92]
logLbreak_s = [52.67, 52.58, 50.74]
nGRB0_s = np.asarray([4.1e-10, 2.4e-10, 2.1e-10])
nGRB0_err_s = 0.3*nGRB0_s  # this is wrong but it doesn't matter as it isnt used by code
labels = ['Zth=0.1', 'Dens. evol.', 'Lum. evol.']
colors = ['mediumpurple', 'C1', 'turquoise']
save_fig = True
if S12:
    paths_to_dir, paths_to_files = io.generate_paths()
    # Cosmology is slightly different
    cosmo = cs.create_cosmology(OmegaM=0.3, OmegaL=0.7, h=0.7, zmax=100)
    for i in range(len(Zth_s)):
        config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
        params['luminosity_function']={'model':'EBPLS12',
                                      'logLbreak':logLbreak_s[i],
                                      'slopeL':slopeL_s[i],
                                      'slopeH':slopeH_s[i],
                                      'logLmin':49,
                                      'logLmax':56,
                                      'k_evol':k_evol_s[i]}
        params['redshift_distribution']={'model':'S12',
                                         'Zth':Zth_s[i],
                                         'n_dens':n_dens_s[i]}
        params['peak_energy_distribution']={'model':'A',
                                            'Ep0':337.,
                                            'alpha_amati':0.49,
                                            'sigmaEp':0.28,
                                            'L0':1.6e52}
        params['spectral_shape']={'model':'Fixed',
                                  'shape':'Band',
                                  'alpha':1,
                                  'beta':2.25}

        plt.style.use('presentation')
        if i==0:
            fig_cstr, axes = plt.subplots(1,3, figsize=(15,4), tight_layout=False)
            plt.style.use('paper')
            fig_SH, ax_SH = plt.subplots(figsize=(8,6))
        gp, fig_cstr = compare_pop(config, samples, instruments, obs_constraints, cosmo, params,
                    color=colors[i], lab=labels[i], fig_cstr=fig_cstr, save_fig=True)
        compare_SHOALS(gp, lab=labels[i], color=colors[i], fig=fig_SH, plot_obs=(i==0), save_fig=True)
        compare_EpL_plane(gp, lab=labels[i], color=colors[i], save_fig=True)

    plt.show()
# Out:
# 20:28:14.758 [INFO] Creating cosmology with: OmegaM = 0.3, OmegaL = 0.7, H0 = 70.0
# 20:28:15.623 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 20:28:15.625 [INFO] Including instruments: ['BATSE', 'BAT']
# 20:28:15.626 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 20:28:16.079 [INFO] Starting calculations of peak photon fluxes...
# 20:28:27.519 [INFO] Starting calculations of peak photon fluxes...
# 20:28:38.384 [INFO] Starting calculations of peak energy fluxes...
# 20:28:57.629 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# 20:28:59.205 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 20:28:59.208 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 20:28:59.227 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 20:28:59.252 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 20:29:00.638 [INFO] In compute_CDF_bounds_by_MC: plotting...
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# 20:29:02.301 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 20:29:02.302 [INFO] Including instruments: ['BATSE', 'BAT']
# 20:29:02.303 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 20:29:02.706 [INFO] Starting calculations of peak photon fluxes...
# 20:29:13.864 [INFO] Starting calculations of peak photon fluxes...
# 20:29:24.790 [INFO] Starting calculations of peak energy fluxes...
# 20:29:44.139 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# 20:29:47.365 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 20:29:47.366 [INFO] Including instruments: ['BATSE', 'BAT']
# 20:29:47.367 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 20:32:16.630 [INFO] Starting calculations of peak photon fluxes...
# 20:32:30.857 [INFO] Starting calculations of peak photon fluxes...
# 20:32:43.213 [INFO] Starting calculations of peak energy fluxes...
# 20:33:06.972 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)

# %%
# Howell 2014
H14 = True
nGRB0 = 6e-10 # yr-1 Mpc-3
nGRB0_err = 0.5e-10 # yr-1 Mpc-3
if H14:
    lab = 'H14'
    color = 'crimson'
    paths_to_dir, paths_to_files = io.generate_paths()
    config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
    # Cosmology is slightly different
    cosmo = cs.create_cosmology(OmegaM=0.32, OmegaL=0.68, h=0.67, zmax=100)
    params['luminosity_function']={'model':'EBPL',
                                  'logLbreak':51.7,
                                  'slopeL':0.5,
                                  'slopeH':2.3,
                                  'logLmin':49,
                                  'logLmax':56,
                                  'k_evol':0.0}
    params['redshift_distribution']={'model':'BPL',
                                     'zm':3.6,
                                     'a':2.1,
                                     'b':-0.7}
    params['peak_energy_distribution']={'model':'Fixed',
                                        'Ep0':511.}
    params['spectral_shape']={'model':'Fixed',
                              'shape':'Band',
                              'alpha':1,
                              'beta':2.25}

    gp, f = compare_pop(config, samples, instruments, obs_constraints, cosmo, params, nGRB0=nGRB0,
                    color=color, lab=lab, fig_cstr=None, save_fig=True)

    compare_SHOALS(gp, lab=lab, color=color, save_fig=True)

    plt.show()
# Out:
# 15:58:42.239 [INFO] Creating cosmology with: OmegaM = 0.32, OmegaL = 0.68, H0 = 67.0
# 15:58:43.126 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 15:58:43.128 [INFO] Including instruments: ['BATSE', 'BAT']
# 15:58:43.129 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 15:58:43.559 [INFO] Starting calculations of peak photon fluxes...
# 15:58:54.925 [INFO] Starting calculations of peak photon fluxes...
# 15:59:06.103 [INFO] Starting calculations of peak energy fluxes...
# 15:59:25.959 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# 15:59:27.600 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 15:59:27.603 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 15:59:27.626 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 15:59:27.657 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 15:59:29.043 [INFO] In compute_CDF_bounds_by_MC: plotting...

# %%
# Daigne 2006 for Amati-like relation
D06 = True
slopes = [1.70, 1.68, 1.54]
logLmins = [49.9, 50.0, 50.3]
logLmaxs = [53.7, 53.7, 53.5]
a_s = [0.320, 0.196, 0.175]
b_s = [3.30, 4.0, 3.67]
c_s = [3.52, 4.0, 3.58]
d_s = [23.6, 14.6, 12.6]
# ngrbs_s = [Nb_GRBs_glob, Nb_GRBs_glob, 10*Nb_GRBs_glob]
nGRB0_s = np.asarray([6.348e-10, 4.905e-10, 1.840e-10])
nGRB0_err_s = 0.3*nGRB0_s  # this is wrong but it doesn't matter as it isnt used by code
labels = ['A-SFR1', 'A-SFR2', 'A-SFR3']
colors = ['C0', 'C3', 'C4']
save_fig = True
if D06:
    paths_to_dir, paths_to_files = io.generate_paths()
    cosmo = cs.create_cosmology(OmegaM=0.3, OmegaL=0.7, h=0.65, zmax=100)
    for i in range(len(slopes)):
        config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
        config['samples'] = ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
        # Cosmology is slightly different
        params['luminosity_function']={'model':'EPL',
                                      'logLmin':logLmins[i],
                                      'logLmax':logLmaxs[i],
                                      'slope':slopes[i],
                                      'k_evol':0.0}
        params['redshift_distribution']={'model':'qD06',
                                        'SFR':i+1,
                                        'mod':'A'}
        params['peak_energy_distribution']={'model':'A',
                                            'Ep0':380.,
                                            'L0':1.6e52,
                                            'alpha_amati':0.43,
                                            'sigmaEp':0.2/np.sqrt(2)}
        params['spectral_shape']={'model':'D06',
                                  'shape':'BPL'}
        if i==0:
            plt.style.use('presentation')
            fig_cstr, axes = plt.subplots(1,3, figsize=(15,4), tight_layout=False)
            plt.style.use('paper')
            fig_SH, ax_SH = plt.subplots(figsize=(8,6))
        gp, fig_cstr = compare_pop(config, samples, instruments, obs_constraints, cosmo, params, nGRB0=nGRB0_s[i],
                    color=colors[i], lab=labels[i], fig_cstr=fig_cstr, save_fig=True)
        compare_SHOALS(gp, lab=labels[i], color=colors[i], fig=fig_SH, plot_obs=(i==0), save_fig=True)
        compare_EpL_plane(gp, lab=labels[i], color=colors[i], save_fig=True)

    plt.show()
# Out:
# 15:59:30.269 [INFO] Creating cosmology with: OmegaM = 0.3, OmegaL = 0.7, H0 = 65.0
# 15:59:31.192 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 15:59:31.193 [INFO] Including instruments: ['BATSE', 'BAT']
# 15:59:31.194 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 15:59:31.622 [INFO] Starting calculations of peak photon fluxes...
# 15:59:40.508 [INFO] Starting calculations of peak photon fluxes...
# 15:59:49.299 [INFO] Starting calculations of peak energy fluxes...
# 16:00:06.685 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# 16:00:08.527 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 16:00:08.530 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 16:00:08.551 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 16:00:08.577 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 16:00:09.953 [INFO] In compute_CDF_bounds_by_MC: plotting...
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# 16:00:11.718 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 16:00:11.720 [INFO] Including instruments: ['BATSE', 'BAT']
# 16:00:11.721 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 16:00:12.173 [INFO] Starting calculations of peak photon fluxes...
# 16:00:21.135 [INFO] Starting calculations of peak photon fluxes...
# 16:00:29.982 [INFO] Starting calculations of peak energy fluxes...
# 16:00:47.363 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# 16:00:50.764 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 16:00:50.765 [INFO] Including instruments: ['BATSE', 'BAT']
# 16:00:50.766 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 16:00:51.255 [INFO] Starting calculations of peak photon fluxes...
# 16:01:00.112 [INFO] Starting calculations of peak photon fluxes...
# 16:01:08.781 [INFO] Starting calculations of peak energy fluxes...
# 16:01:26.096 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)

# %%
# Daigne 2006 for LogNormal relation
D06 = True
slopes = [1.62, 1.62, 1.52]
logLmins = [50.2, 50.2, 50.5]
logLmaxs = [53.6, 53.6, 53.7]
Ep0s = [10**2.74, 10**2.73, 10**2.79]
a_s = [0.320, 0.196, 0.175]
b_s = [3.30, 4.0, 3.67]
c_s = [3.52, 4.0, 3.58]
d_s = [23.6, 14.6, 12.6]
ngrbs_s = [10*Nb_GRBs_glob, 10*Nb_GRBs_glob, 10*Nb_GRBs_glob]
nGRB0_s = np.asarray([3.967e-10, 3.066e-10, 1.580e-10])  # 9.890e-11
nGRB0_err_s = 0.3*nGRB0_s # this is wrong but it doesn't matter as it isnt used by code
labels = ['LN-SFR1', 'LN-SFR2', 'LN-SFR3']
colors = ['C1', 'C2', 'C9']
if D06:
    paths_to_dir, paths_to_files = io.generate_paths()
    cosmo = cs.create_cosmology(OmegaM=0.3, OmegaL=0.7, h=0.65, zmax=100)
    for i in range(len(slopes)):
        config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
        config['samples'] = ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
        # Cosmology is slightly different
        params['luminosity_function']={'model':'EPL',
                                      'logLmin':logLmins[i],
                                      'logLmax':logLmaxs[i],
                                      'slope':slopes[i],
                                      'k_evol':0.0}
        params['redshift_distribution']={'model':'qD06',
                                         'SFR':i+1,
                                         'mod':'LN'}
        params['peak_energy_distribution']={'model':'LN',
                                            'Ep0':Ep0s[i],
                                            'sigmaEp':0.3/np.sqrt(2)}
        params['spectral_shape']={'model':'D06',
                                  'shape':'BPL'}

        if i==0:
            plt.style.use('presentation')
            fig_cstr, axes = plt.subplots(1,3, figsize=(15,4), tight_layout=False)
            plt.style.use('paper')
            fig_SH, ax_SH = plt.subplots(figsize=(8,6))
        gp, fig_cstr = compare_pop(config, samples, instruments, obs_constraints, cosmo, params, nGRB0=nGRB0_s[i],
                    color=colors[i], lab=labels[i], fig_cstr=fig_cstr, save_fig=True)
        compare_SHOALS(gp, lab=labels[i], color=colors[i], fig=fig_SH, plot_obs=(i==0), save_fig=True)
        compare_EpL_plane(gp, lab=labels[i], color=colors[i], save_fig=True)

    plt.show()
# Out:
# 16:01:32.810 [INFO] Creating cosmology with: OmegaM = 0.3, OmegaL = 0.7, H0 = 65.0
# 16:01:33.703 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 16:01:33.704 [INFO] Including instruments: ['BATSE', 'BAT']
# 16:01:33.705 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 16:01:34.101 [INFO] Starting calculations of peak photon fluxes...
# 16:01:42.986 [INFO] Starting calculations of peak photon fluxes...
# 16:01:51.623 [INFO] Starting calculations of peak energy fluxes...
# 16:02:09.160 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# 16:02:10.812 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 16:02:10.814 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 16:02:10.835 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 16:02:10.862 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 16:02:12.248 [INFO] In compute_CDF_bounds_by_MC: plotting...
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# 16:02:14.072 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 16:02:14.074 [INFO] Including instruments: ['BATSE', 'BAT']
# 16:02:14.075 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 16:02:14.496 [INFO] Starting calculations of peak photon fluxes...
# 16:02:23.491 [INFO] Starting calculations of peak photon fluxes...
# 16:02:32.280 [INFO] Starting calculations of peak energy fluxes...
# 16:02:49.746 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# 16:02:53.141 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'SHOALS']
# 16:02:53.143 [INFO] Including instruments: ['BATSE', 'BAT']
# 16:02:53.143 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 16:02:53.555 [INFO] Starting calculations of peak photon fluxes...
# 16:03:02.502 [INFO] Starting calculations of peak photon fluxes...
# 16:03:11.075 [INFO] Starting calculations of peak energy fluxes...
# 16:03:28.402 [INFO] Starting calculations of detection probability...
# Sample size :1313
# Sample size :82
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)

# %%
_Stern_constr = {'Stern': {'instrument': 'BATSE',
  'val_min': 0.066825,
  'prop_min': 'pht_pflx_BATSE',
  'quantity': 'pht_pflx_BATSE',
  'sum_ln_oi_factorial': 36306.10949982049,
  'last_bin': 50.0,
  'bins': np.array([ 0.066825 ,  0.0841276,  0.10591  ,  0.133333 ,  0.167857 ,
          0.211319 ,  0.266035 ,  0.334918 ,  0.421637 ,  0.53081  ,
          0.66825  ,  0.841276 ,  1.0591   ,  1.33333  ,  1.67857  ,
          2.11319  ,  2.66035  ,  3.34918  ,  4.21637  ,  5.3081   ,
          6.6825   ,  8.41277  , 10.591    , 13.3333   , 16.       ,
         20.       , 28.       , 50.       ]),
  'hist': np.array([746.998 , 709.321 , 756.005 , 617.559 , 621.942 , 518.764 ,
         425.721 , 379.296 , 340.3   , 301.492 , 291.045 , 247.761 ,
         244.776 , 201.493 , 180.597 , 131.343 , 126.866 ,  83.5821,
          73.1344,  65.6715,  37.3135,  35.8208,  31.3433,  23.8806,
          22.388 ,  17.9104,  16.4179]),
  'err': np.array([186.75   ,  91.5729 ,  64.8269 ,  43.3442 ,  35.381  ,  28.9998 ,
          25.3513 ,  23.7992 ,  22.5369 ,  21.2129 ,  20.8421 ,  19.23   ,
          19.1138 ,  17.3417 ,  16.4179 ,  14.0012 ,  13.7605 ,  11.1691 ,
          10.4478 ,   9.90036,   7.46269,   7.3119 ,   6.83967,   5.97015,
           5.78057,   5.17029,   4.95019])}}
