# %%
import sys
src_dir = '/Users/palmerio/Science_projects/GRB_population_model/src/'
sys.path.insert(0, src_dir)
verbose = True
run_mode = 'debug'

# GRB pop module imports
from GRB_population import GRBPopulation
import physics as ph
import stats as st
import io_grb_pop as io
import miscellaneous as msc
import plotting_functions as pf
from cosmology import init_cosmology
from ECLAIRs import init_ECLAIRs

# General imports
import yaml
import logging
import corner
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# specific imports
from scipy.stats import ks_2samp
from scipy.stats import mstats
from itertools import product

log = logging.getLogger(__name__)
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG,
                    format='%(asctime)s.%(msecs)03d [%(levelname)s] %(message)s',
                    datefmt='%H:%M:%S')
logging.getLogger('matplotlib').setLevel(logging.WARNING)

plt.style.use('paper')

# %%
paths_to_dir, paths_to_files = io.generate_paths()
# Out:
# 10:42:51.088 [DEBUG] Root directory is /Users/palmerio/Science_projects/GRB_population_model
# 10:42:51.089 [DEBUG] Directory paths :
#     'root'    : /Users/palmerio/Science_projects/GRB_population_model
#     'obs'     : /Users/palmerio/Science_projects/GRB_population_model/observational_constraints
#     'init'    : /Users/palmerio/Science_projects/GRB_population_model/init
#     'output'  : /Users/palmerio/Science_projects/GRB_population_model/model_outputs
#     'data'    : /Users/palmerio/Science_projects/GRB_population_model/data
#     'cosmo'   : /Users/palmerio/Science_projects/GRB_population_model/data/cosmology
#     'ECLAIRs' : /Users/palmerio/Science_projects/GRB_population_model/data/ECLAIRs
# 10:42:51.090 [DEBUG] File paths :
#     'config'          : /Users/palmerio/Science_projects/GRB_population_model/init/config.yml
#     'param'           : /Users/palmerio/Science_projects/GRB_population_model/init/parameters.yml
#     'instrum'         : /Users/palmerio/Science_projects/GRB_population_model/init/instruments.yml
#     'sample'          : /Users/palmerio/Science_projects/GRB_population_model/init/samples.yml
#     'obs_constraints' : /Users/palmerio/Science_projects/GRB_population_model/init/obs_constraints.yml

# %%
config, params, instruments, samples, obs_constraints = io.read_init_files(paths_to_files)
paths_to_dir['output'] = '/Users/palmerio/Science_projects/GRB_population_model/model_outputs/best_populations'
cosmo = init_cosmology(paths_to_dir['cosmo'])
ECLAIRs_prop = init_ECLAIRs(ECLAIRs_dir=paths_to_dir['ECLAIRs'],
                            ECLAIRs_config=instruments['ECLAIRs'])
samples['ECLAIRs']['pflx_min'] = ECLAIRs_prop['bkg_total']

Nb_GRBs = int(1e6)

incl_samples, incl_instruments, incl_constraints = io.create_config(config,
                                                                     samples,
                                                                     instruments,
                                                                     obs_constraints)
# Out:
# 10:42:51.120 [DEBUG] Input configuration:
# Nb_GRBs: 1e5
# constraints:
# - Stern
# - EpGBM
# - eBAT6
# output_dir: debugger
# samples:
# - Stern
# - EpGBM
# - eBAT6
# - Swift
# - ECLAIRs
# - SHOALS
# - GBM_sample
# - BATSE_5B_sample
#
# 10:42:51.123 [DEBUG] Input parameters:
# Cvar_distribution:
#     correl_slope: -0.413
#     mu: 0.04
#     sigma: 0.22
# luminosity_function:
#     k_evol: 1.0
#     logLbreak: 52.56
#     logLmax: 53.0
#     logLmin: 49.6989700043
#     model: ES
#     slope: 1.41
# peak_energy_distribution:
#     Ep0: 690
#     alpha_amati: 0.3
#     model: LN
#     sigmaEp: 0.45
# redshift_distribution:
#     a: 0.94
#     b: -0.52
#     model: BExp
#     zeta: null
#     zm: 2.18
#     zmax: 20
# spectral_shape:
#     alpha: 0.6
#     beta: 2.5
#     model: GBM_Band
# t90obs_distribution:
#     mu: 1.45
#     sigma: 0.47
#
# 10:42:51.130 [DEBUG] ==============================================
# 10:42:51.130 [DEBUG] ===           ECLAIRs instrument           ===
# 10:42:51.131 [DEBUG] ==============================================
# 10:42:51.131 [DEBUG] ECLAIRs energy channel: 4.0 to 150.0 keV
# 10:42:51.132 [DEBUG] ECLAIRs detection level: 6.5 sigmas
# 10:42:51.169 [DEBUG] Effective area: from 1.013650e+02 cm2 at 4.00 keV
# 10:42:51.170 [DEBUG] Effective area: to   1.811580e+02 cm2 at 250.00 keV
# 10:42:51.170 [DEBUG] Background: from 2.819620e+02 cts/s/keV at 4.00 keV
# 10:42:51.172 [DEBUG] Background: to   8.730200e-02 cts/s/keV at 250.00 keV
# 10:42:51.173 [DEBUG] ECLAIRs background: 3.098396e+03 cts/s from 4.00 keV to 150.00 keV
# 10:42:51.174 [DEBUG] ==============================================
# 10:42:51.175 [INFO] Including samples: ['Stern', 'EpGBM', 'eBAT6', 'Swift', 'ECLAIRs', 'SHOALS', 'GBM_sample', 'BATSE_5B_sample']
# 10:42:51.178 [DEBUG] Including samples:
# BATSE_5B_sample:
#     instrument: BATSE_5B
#     pflx_min: 1.0
# ECLAIRs:
#     instrument: ECLAIRs
#     pflx_min: 3098.396271499998
# EpGBM:
#     instrument: BATSE
#     pflx_min: 0.9
# GBM_sample:
#     instrument: GBM
#     pflx_min: 3.0
# SHOALS:
#     instrument: BAT
#     pflx_min: 1.0e-06
# Stern:
#     instrument: BATSE
#     pflx_min: 0.066825
# Swift:
#     instrument: BAT
#     pflx_min: 0.2
# eBAT6:
#     instrument: BAT
#     pflx_min: 2.6
#
# 10:42:51.178 [INFO] Including instruments: ['BATSE', 'BAT', 'ECLAIRs', 'GBM', 'BATSE_5B']
# 10:42:51.180 [DEBUG] Including instruments:
# BAT:
#     Emax: 150.0
#     Emin: 15.0
# BATSE:
#     Emax: 300.0
#     Emin: 50.0
# BATSE_5B:
#     Emax: 2000.0
#     Emin: 20.0
# ECLAIRs:
#     Emax: 150.0
#     Emin: 4.0
#     n_sigma: 6.5
# GBM:
#     Emax: 1000.0
#     Emin: 10.0
#
# 10:42:51.181 [INFO] Including constraints: ['Stern', 'EpGBM', 'eBAT6']
# 10:42:51.184 [DEBUG] Including constraints:
# EpGBM:
#     instrument: BATSE
#     last_bin: 10000
#     prop_min: pht_pflx_BATSE
#     quantity: Epobs
#     sum_ln_oi_factorial: 4168.986506912058
#     val_min: 0.9
# Stern:
#     instrument: BATSE
#     last_bin: 50.0
#     prop_min: pht_pflx_BATSE
#     quantity: pht_pflx_BATSE
#     sum_ln_oi_factorial: 36306.10949982049
#     val_min: 0.066825
# eBAT6:
#     instrument: BAT
#     last_bin: 6.0
#     prop_min: pht_pflx_BAT
#     quantity: z
#     sum_ln_oi_factorial: 95.89913351276238
#     val_min: 2.6

# %%
# Generate the populations for the best model in each scenario or load the populations from files
# WARNING : this takes a long time to compute (at least 30 min with Nb_GRBs = 1e6)
##################

load_files = True
old = True

##################


np.random.seed(1)
model_names = ['kF_LN_nSFR',
               'k0_LN_nF', 
               'k05_LN_nF', 
               'k1_LN_nF', 
               'k2_LN_nF', 
               'kF_A_nSFR',
               'k0_A_nF', 
               'k05_A_nF',
               'k05_A_nF_2',
               'k1_A_nF', 
               'k1_A_nF_2', 
               'k2_A_nF']

model_names_ks = ['k0_LN_nF', 'k2_LN_nF', 'k0_A_nF', 'k2_A_nF']
# colors = ['#225ea8', '#41b6c4', '#ae017e', '#f768a1']
colors = ['#225ea8', '#41b6c4', '#d94801', '#fd8d3c']

parameters = {}
dfs = {}
results = {}
for mod in model_names:
    if load_files:
        print(f'Loading {mod}... ', end='')
        dfs[mod] = io.load_GRBPopulation_from(f'../model_outputs_non-dockerized/best_populations/population_{mod}')
        print('Done')
    else:
        print(f'Calculating {mod}... ')
        with open(paths_to_files['param'].parent / f'parameters_{mod}.yml', 'r') as f:
            parameters[mod] = yaml.safe_load(f)

        dfs[mod] = GRBPopulation(Nb_GRBs, output_dir=paths_to_dir['output'])
        dfs[mod].draw_GRB_properties(cosmo=cosmo, params=parameters[mod], run_mode=None)
        dfs[mod].calculate_quantities(instruments=incl_instruments, samples=incl_samples, ECLAIRs_prop=ECLAIRs_prop)
        dfs[mod].create_mock_constraints(constraints=incl_constraints)
        dfs[mod].compare_to_observational_constraints(constraints=incl_constraints)
        dfs[mod].normalize_to_Stern()
# Out:
# Loading kF_LN_nSFR... Done
# Loading k0_LN_nF... Done
# Loading k05_LN_nF... Done
# Loading k1_LN_nF... Done
# Loading k2_LN_nF... Done
# Loading kF_A_nSFR... Done
# Loading k0_A_nF... Done
# Loading k05_A_nF... Done
# Loading k05_A_nF_2... Done
# Loading k1_A_nF... Done
# Loading k1_A_nF_2... Done
# Loading k2_A_nF... Done

# %%
dfs_old = {}
for mod in model_names[0:1]:
    print(f'Loading {mod}... ', end='')
    dfs_old[mod] = GRBPopulation(properties=pd.read_parquet(f'../model_outputs_non-dockerized/best_populations_old/population_{mod}'))
    dfs_old[mod].create_mock_constraints()
    dfs_old[mod].compare_to_observational_constraints(constraints=incl_constraints)
    print('Done')
    fig_prop, fig_pflx, fig_samp = examine_pop(dfs_old[mod], label='Old', alpha=0.5)
    examine_pop(dfs[mod], fig_prop=fig_prop, fig_pflx=fig_pflx, fig_samp=fig_samp, label='New', alpha=0.5)
    
#     dfs_old[mod].normalize_to_Stern()
# Out:
# Loading kF_LN_nSFR... Done
# pflx keys: ['pht_pflx_BATSE', 'pht_pflx_BAT', 'pht_cts_ECLAIRs', 'pht_pflx_GBM', 'pht_pflx_BATSE_5B', 'erg_pflx_BATSE', 'erg_pflx_BAT', 'erg_cts_ECLAIRs', 'erg_pflx_GBM', 'erg_pflx_BATSE_5B']
# Sampe names ['Stern', 'EpGBM', 'eBAT6', 'Swift', 'ECLAIRs_tot', 'ECLAIRs_pht_flnc', 'ECLAIRs_pht_cts', 'SHOALS', 'GBM_sample', 'BATSE_5B_sample']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/python3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pdet_ECLAIRs_tot_tot'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-8f27ba9a6ee2> in <module>
#       6     dfs_old[mod].compare_to_observational_constraints(constraints=incl_constraints)
#       7     print('Done')
# ----> 8     fig_prop, fig_pflx, fig_samp = examine_pop(dfs_old[mod], label='Old', alpha=0.5)
#       9     examine_pop(dfs[mod], fig_prop=fig_prop, fig_pflx=fig_pflx, fig_samp=fig_samp, label='New', alpha=0.5)
#      10
#
# <ipython-input-41-64a5e33e4f2d> in examine_pop(pop, fig_prop, fig_pflx, fig_samp, label, **kwargs)
#      50             weight = 'pdet_'+samp
#      51             ax.set_xlabel(f"log(pflx {samp})".replace('_',' '))
# ---> 52         ax.hist(np.log10(df[instrum]), weights=df[weight], bins=np.arange(pflx_min, 7, 0.15), label=label, density=True, **kwargs)
#      53         ax.set_xlim(pflx_min, np.log10(df[instrum].max()))
#      54         ax.set_yscale('log')
#
# ~/miniconda3/envs/python3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/miniconda3/envs/python3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pdet_ECLAIRs_tot_tot'

# %%
dfs[mod].properties.columns
# Out:
# Index(['z', 'L', 'Ep', 'alpha', 'beta', 'ktild', 'D_L', 'Epobs',
#        'pht_pflx_BATSE', 't90', 't90obs', 'Cvar', 'Eiso', 'pht_pflx_BAT',
#        'pht_cts_ECLAIRs', 'pht_pflx_GBM', 'pht_pflx_BATSE_5B',
#        'erg_pflx_BATSE', 'erg_pflx_BAT', 'erg_cts_ECLAIRs', 'erg_pflx_GBM',
#        'erg_pflx_BATSE_5B', 'pht_flnc_BATSE', 'pht_flnc_BAT',
#        'pht_flnc_ECLAIRs', 'pht_flnc_GBM', 'pht_flnc_BATSE_5B',
#        'erg_flnc_BATSE', 'erg_flnc_BAT', 'erg_flnc_ECLAIRs', 'erg_flnc_GBM',
#        'erg_flnc_BATSE_5B', 'pdet_Stern', 'pdet_EpGBM', 'pdet_eBAT6',
#        'pdet_Swift', 'pdet_ECLAIRs_tot', 'pdet_ECLAIRs_pht_flnc',
#        'pdet_ECLAIRs_pht_cts', 'pdet_SHOALS', 'pdet_GBM_sample',
#        'pdet_BATSE_5B_sample'],
#       dtype='object')

# %%
def examine_pop(pop, fig_prop=None, fig_pflx=None, fig_samp=None, label=None, **kwargs):
    df = pop.properties

    if fig_prop is None:
        fig_prop, axes_prop = plt.subplots(2, 4, figsize=(14, 6), tight_layout=True)
    else:
        axes_prop = np.array(fig_prop.get_axes())

    prop_name = ['z', 'L', 'Ep', 't90', 'Cvar', 'alpha', 'beta', 'ktild']
    are_log = [False, True, True, True, True, False, False, False]
    bins_lims = [(0, 20), (49, 55), (0, 5), (-0.5, 3.5), (-2, 0), (-1, 2), (2, 25), (0, 15)]

    for ax, prop, is_log, bins_lim in zip(axes_prop.flatten(), prop_name, are_log, bins_lims):
        if is_log:
            ax.hist(np.log10(df[prop]), bins=np.linspace(bins_lim[0], bins_lim[1], 20), label=label, density=True, **kwargs)
            ax.set_xlabel(f"log({prop})".replace('_',' '))
        else:
            ax.hist(df[prop], bins=np.linspace(bins_lim[0], bins_lim[1], 20), label=label, density=True, **kwargs)
            ax.set_xlabel(f"{prop}".replace('_',' '))
        ax.set_yscale('log')
        ax.legend()

    pflx_name = [key for key in df.columns if (('pflx_' in key) or ('cts_' in key))]
    print('pflx keys: {}'.format(pflx_name))
    if fig_pflx is None:
        fig_pflx, axes_pflx = plt.subplots(1, len(pflx_name), figsize=(3.5*len(pflx_name), 4.5), tight_layout=True)
    else:
        axes_pflx = np.array(fig_pflx.get_axes())
    for ax, pflx in zip(axes_pflx.flatten(), pflx_name):
        ax.hist(np.log10(df[pflx]), bins=np.arange(-20, 6, 0.5), label=label, density=True, **kwargs)
        ax.set_xlabel(f"log({pflx})".replace('_',' '))
        ax.set_xlim(np.log10(df[pflx].min()), np.log10(df[pflx].max()))
        ax.set_yscale('log')
        ax.legend()

#     samp_name = set([key[5:] for key in df.columns if ('pdet_' in key)])
#     print('Sampe names {}'.format(samp_name))
#     if fig_samp is None:
#         fig_samp, axes_samp = plt.subplots(1, len(samp_name), figsize=(3.5*len(samp_name), 4.5), tight_layout=True)
#     else:
#         axes_samp = np.array(fig_samp.get_axes())
#     for ax, samp in zip(axes_samp.flatten(), samp_name):
#         if 'ECLAIRs' in samp:
#             instrum = '_'.join(['pht', 'cts', samples[samp.split('_')[0]]['instrument']])
#             weight = 'pdet_'+samp+'_tot'
#             ax.set_xlabel(f"log(cts {samp})".replace('_',' '))
#         else:
#             pflx_min = np.log10(float(samples[samp]['pflx_min']))
#             instrum = '_'.join(['pht','pflx', samples[samp]['instrument']])
#             weight = 'pdet_'+samp
#             ax.set_xlabel(f"log(pflx {samp})".replace('_',' '))
#         ax.hist(np.log10(df[instrum]), weights=df[weight], bins=np.arange(pflx_min, 7, 0.15), label=label, density=True, **kwargs)
#         ax.set_xlim(pflx_min, np.log10(df[instrum].max()))
#         ax.set_yscale('log')
#         ax.legend()

    return fig_prop, fig_pflx, fig_samp

# %%
# Save the best populations to avoid recalculating each time
if not load_files:
    for mod in model_names:
        dfs[mod].save_to(paths_to_dir['output'] + f'/population_{mod}')

# %%
ECLAIRs_prop['omega_ECLAIRs_tot']
# Out:
# 2.0517826253

# %%
# Calculate the predicted rate for SVOM/ECLAIRs
sky_frac = ECLAIRs_prop['omega_ECLAIRs_tot'] / (4*np.pi)
frac_T_live_ECLAIRs = 0.53  #  T_live / T_mission
for mod in model_names:
    print(f" {mod} ".center(45, '#'))
    results[mod] = {}
    results[mod]['T_sim'] = dfs[mod].normalization['T_sim']
    results[mod]['T_sim_err'] = dfs[mod].normalization['T_sim_err']
    results[mod]['R_intr'] = dfs[mod].normalization['R_intr']
    results[mod]['R_intr_err'] = dfs[mod].normalization['R_intr_err']
    results[mod]['ECLAIRs_cts_rate'] = np.sum(dfs[mod].properties['pdet_ECLAIRs_pht_cts']) * frac_T_live_ECLAIRs / dfs[mod].normalization['T_sim']
    results[mod]['ECLAIRs_flnc_rate'] = np.sum(dfs[mod].properties['pdet_ECLAIRs_pht_flnc']) * frac_T_live_ECLAIRs / dfs[mod].normalization['T_sim']
    results[mod]['ECLAIRs_tot_rate'] = np.sum(dfs[mod].properties['pdet_ECLAIRs_tot']) * frac_T_live_ECLAIRs / dfs[mod].normalization['T_sim']
    print(45*'#')
# Out:
# ## kF_LN_nSFR #
# ###############
# ### k0_LN_nF ##
# ###############
# ## k05_LN_nF ##
# ###############
# ### k1_LN_nF ##
# ###############
# ### k2_LN_nF ##
# ###############
# ## kF_A_nSFR ##
# ###############
# ### k0_A_nF ###
# ###############
# ### k05_A_nF ##
# ###############
# ## k05_A_nF_2 #
# ###############
# ### k1_A_nF ###
# ###############
# ## k1_A_nF_2 ##
# ###############
# ### k2_A_nF ###
# ###############

# %%
# Out:
# ################# kF_LN_nSFR #####################
# 18:33:34.174 [INFO]           EpGBM chi2: 1.3630e+01
# 18:33:34.174 [INFO]  EpGBM normalization: 1.3185e-02
# ################################################
# ################# k0_LN_nF #####################
# 18:33:34.530 [INFO]           EpGBM chi2: 1.0703e+01
# 18:33:34.531 [INFO]  EpGBM normalization: 4.5920e-02
# ################################################
# ################# k05_LN_nF #####################
# 18:33:34.970 [INFO]           EpGBM chi2: 1.0159e+01
# 18:33:34.971 [INFO]  EpGBM normalization: 2.4445e-02
# ################################################
# ################# k1_LN_nF #####################
# 18:33:35.775 [INFO]           EpGBM chi2: 1.0937e+01
# 18:33:35.775 [INFO]  EpGBM normalization: 1.6747e-02
# ################################################
# ################# k2_LN_nF #####################
# 18:33:36.183 [INFO]           EpGBM chi2: 1.2894e+01
# 18:33:36.184 [INFO]  EpGBM normalization: 1.0388e-02
# ################################################
# ################# kF_A_nSFR #####################
# 18:33:36.638 [INFO]           EpGBM chi2: 1.0089e+01
# 18:33:36.638 [INFO]  EpGBM normalization: 9.4789e-03
# ################################################
# ################# k0_A_nF #####################
# 18:33:37.012 [INFO]           EpGBM chi2: 1.1923e+01
# 18:33:37.012 [INFO]  EpGBM normalization: 3.8317e-02
# ################################################
# ################# k05_A_nF #####################
# 18:33:37.376 [INFO]           EpGBM chi2: 2.0971e+01
# 18:33:37.377 [INFO]  EpGBM normalization: 3.3601e-02
# ################################################
# ################# k05_A_nF_2 #####################
# 18:33:37.741 [INFO]           EpGBM chi2: 1.0145e+01
# 18:33:37.742 [INFO]  EpGBM normalization: 2.4043e-02
# ################################################
# ################# k1_A_nF #####################
# 18:33:38.392 [INFO]           EpGBM chi2: 1.3124e+01
# 18:33:38.392 [INFO]  EpGBM normalization: 1.9353e-02
# ################################################
# ################# k1_A_nF_2 #####################
# 18:33:38.998 [INFO]           EpGBM chi2: 1.0925e+01
# 18:33:38.999 [INFO]  EpGBM normalization: 2.2610e-02
# ################################################
# ################# k2_A_nF #####################
# 18:33:39.420 [INFO]           EpGBM chi2: 1.1694e+01
# 18:33:39.420 [INFO]  EpGBM normalization: 9.8793e-03
# ################################################

# %%
df_res = pd.DataFrame(results)
df_res
# Out:
#                     kF_LN_nSFR     k0_LN_nF    k05_LN_nF     k1_LN_nF  \
# T_sim               372.636036   112.833333   201.981982   283.145045
# T_sim_err            13.428326     4.066066     7.278630    10.203425
# R_intr             2683.583721  8862.629247  4950.936664  3531.758784
# R_intr_err           96.705720   319.374027   178.412132   127.270587
# ECLAIRs_cts_rate    111.365390   111.888353   114.229747   114.831572
# ECLAIRs_flnc_rate   153.959371   158.996173   160.649829   158.019723
# ECLAIRs_tot_rate    158.808303   163.833656   165.528190   162.987021
#
#                       k2_LN_nF    kF_A_nSFR      k0_A_nF     k05_A_nF  \
# T_sim               474.809009   535.126126   131.149550   153.003604
# T_sim_err            17.110235    19.283824     4.726110     5.513643
# R_intr             2106.109996  1868.718329  7624.883223  6535.793775
# R_intr_err           75.895856    67.341201   274.770567   235.524100
# ECLAIRs_cts_rate    110.395861   123.216206   125.608875   147.461552
# ECLAIRs_flnc_rate   153.077250   176.605659   183.211430   224.264993
# ECLAIRs_tot_rate    157.877110   182.484461   189.199881   232.018791
#
#                     k05_A_nF_2      k1_A_nF    k1_A_nF_2      k2_A_nF
# T_sim               210.272072   261.000901   217.704505   508.929730
# T_sim_err             7.577372     9.405438     7.845207    18.339810
# R_intr             4755.743310  3831.404400  4593.382219  1964.907809
# R_intr_err          171.378137   138.068627   165.527287    70.807489
# ECLAIRs_cts_rate    113.345553   132.242361   154.471485   123.211040
# ECLAIRs_flnc_rate   161.499890   194.327939   235.405615   176.117152
# ECLAIRs_tot_rate    166.718841   200.814494   243.571820   181.968252

# %%
# Plot the redshift distribution expected for SHOALS in the case of k=0 and k=2 for LogNormal and Amati models
# Also compute the KS tests between these redshift distributions and the observed SHOALS redshift distribution
fig, ax = plt.subplots(figsize=(8,6))
df_obs = io.read_SHOALS_file()
pf.plot_SHOALS_z_distr_with_bounds(ax=ax)
for i,mod in enumerate(model_names_ks):
    print(f"################# {mod} #####################")
    cond = dfs[mod].properties['pdet_SHOALS']==1
    pf.plot_SHOALS_distr(dfs[mod],
                          key='z',
                          plot_obs=False,
                          cumul=True,
                          ax=ax,
                          mod_color=colors[i],
                          mod_label=mod.replace('_',' '))
    D_stat, p_value = ks_2samp(dfs[mod].properties[cond]['z'], df_obs['z'])
    print("D-stat = {:.3f}  p_value = {:.3f}".format(D_stat, p_value))
ax.set_xlabel('Redshift (z)')
ax.set_xlim(0,8)
# plt.savefig('/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/SHOALS_z_distr.pdf')
plt.show()
# Out:
# 21:10:16.076 [INFO] In compute_CDF_bounds_by_MC: initializing...
# 21:10:16.089 [INFO] In compute_CDF_bounds_by_MC: starting Monte Carlo drawings...
# 21:10:16.121 [INFO] In compute_CDF_bounds_by_MC: starting bootstraps...
# 21:10:16.157 [INFO] In compute_CDF_bounds_by_MC: computing CDF...
# 21:10:17.626 [INFO] In compute_CDF_bounds_by_MC: plotting...
# ################# k0_LN_nF #####################
# D-stat, p_value = 0.077, 0.523
# ################# k2_LN_nF #####################
# D-stat, p_value = 0.058, 0.853
# ################# k0_A_nF #####################
# D-stat, p_value = 0.057, 0.865
# ################# k2_A_nF #####################
# D-stat, p_value = 0.049, 0.950
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Since all the redshift distribution of SHOALS look the same, I looked at the redshift distribution
# of the whole LGRB population, which is plotted below
fig, ax = plt.subplots(figsize=(10,8))
ax.set_title('Redshift distribution for the entire LGRB population', **{'size':20})
# colors = ['#225ea8', '#41b6c4', '#ae017e', '#f768a1']
for i,mod in enumerate(model_names_ks):
    x_mod, cdf_mod = st.unbinned_empirical_cdf(dfs[mod].properties['z'])
    ax.plot(x_mod, cdf_mod, color=colors[i], drawstyle='steps-post', label=mod.replace('_',' '))

ax.legend(loc='lower right')
ax.set_ylabel('CDF')
ax.set_ylim(0,1)
ax.set_xlim(0,15)
ax.set_xlabel('Redshift (z)')
plt.show()

# %%
# Clearly the sample size and fluence cut of SHOALS don't allow us to discriminate between k=0 and k=2 models
# What fluence cut and sample size is needed to discriminate between k=0 and k=2 models?
# To answer this we create subsamples of size N_SHOALS=117 from the k=0 redshift distribution and compute
# the K-S test between these subsamples and the entire k=2 sample.
# This is repeated N_bs times (bs stands for bootstrap) to get an idea of how robust the results are.
# For each subsample we compute the K-S test and obtain the D-statistic and the p-value for that realization.
# The resulting distributions of D-statistics and p-values and shown in the bottom panels of the figure
# The top panel shows the CDF and the confidence bounds around it are calculated from the bootstrapping as well.
# The fraction of bootstrap samples that have p-value below 0.05 is shown in the legend of the bottom right panel
N_bs = 1000
N_sub = 117
thrsh = 1e-6
precision=500
st.subsample_and_KS(dfs['k0_LN_nF'].properties[(dfs['k0_LN_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 dfs['k2_LN_nF'].properties[(dfs['k2_LN_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 key='z',
                 precision=precision,
                 bins=np.linspace(0,20,precision+1),
                 N_sub=N_sub,
                 N_bs=N_bs,
                 label1='k0 LN nF',
                 label2='k2 LN nF',
                 show_plot=True, subsample2=False)
fig = plt.gcf()
axes = fig.axes
axes[0].set_xlim(0,8)
df_SHOALS = io.read_SHOALS_file()
z_SHOALS = df_SHOALS['z'].to_numpy()
x_obs, cdf_obs = st.unbinned_empirical_cdf(z_SHOALS)
axes[0].plot(x_obs, cdf_obs, color='C5', drawstyle='steps-post', label='SHOALS observed', lw=3)

axes[0].legend()
axes[0].set_title('Comparison between the z distribution of the k=0 and k=2 LN models\n above\
                  {:.0e} erg/cm2 using K-S tests and bootstrapping'.format(thrsh), **{'size':15})
plt.show()
# Out:
# 21:18:05.082 [INFO] Subsampling done in 1.127 s
# 21:18:23.711 [INFO] KS calculations done in 18.628 s
# 21:18:35.080 [INFO] CDF calculation done in 11.369 s

# %%
# The following is to show that the results don't change if we subsample from the k=2 scenario instead
# and compare with the entire k=0 redshift distribution.
st.subsample_and_KS(dfs['k0_LN_nF'].properties[(dfs['k0_LN_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 dfs['k2_LN_nF'].properties[(dfs['k2_LN_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 key='z',
                 precision=precision,
                 bins=np.linspace(0,20,precision+1),
                 N_sub=N_sub,
                 N_bs=N_bs,
                 label1='k0 LN nF',
                 label2='k2 LN nF',
                 show_plot=True, subsample1=False)
fig = plt.gcf()
axes = fig.axes
axes[0].set_xlim(0,8)
obs.plot_observed_SHOALS_z_distr(axes[0], color='C5', lw=3, label='SHOALS observed')
axes[0].legend()
axes[0].set_title('Comparison between the z distribution of the k=0 and k=2 LN models\n above\
              {:.0e} erg/cm2 using K-S tests and bootstrapping'.format(thrsh), **{'size':15})
plt.show()
# Out:
# 17:28:04.264 [INFO] Subsampling done in 2.672 s
# 17:28:07.480 [INFO] KS calculations done in 3.215 s
# 17:28:09.534 [INFO] CDF calculation done in 2.054 s

# %%
# Here we do the same thing but with the Amati-like scenarios
N_bs = 1000
N_sub = 117
thrsh = 1e-7
precision=500
st.subsample_and_KS(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 key='z',
                 precision=precision,
                 bins=np.linspace(0,20,precision+1),
                 N_sub=N_sub,
                 N_bs=N_bs,
                 label1='k0 A nF',
                 label2='k2 A nF',
                 show_plot=True, subsample1=False)
fig = plt.gcf()
axes = fig.axes
axes[0].set_xlim(0,8)
obs.plot_observed_SHOALS_z_distr(axes[0], color='C5', lw=3, label='SHOALS observed')
axes[0].legend()
axes[0].set_title('Comparison between the z distribution of the k=0 and k=2 A models\n above\
              {:.0e} erg/cm2 using K-S tests and bootstrapping'.format(thrsh), **{'size':15})
plt.show()
# Out:
# 17:29:23.104 [INFO] Subsampling done in 14.481 s
# 17:29:45.986 [INFO] KS calculations done in 22.882 s
# 17:29:59.928 [INFO] CDF calculation done in 13.941 s

# %%
# It seems it is much harder to discriminate between the k=0 and k=2 models, even at deep fluence cuts for the
# Amati-like scenarios
thrsh = 1e-8
st.subsample_and_KS(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['erg_flnc_BAT']>=thrsh)],
                 key='z',
                 precision=precision,
                 bins=np.linspace(0,20,precision+1),
                 N_sub=N_sub,
                 N_bs=N_bs,
                 label1='k0 A nF',
                 label2='k2 A nF',
                 show_plot=True, subsample1=False)
fig = plt.gcf()
axes = fig.axes
axes[0].set_xlim(0,8)
obs.plot_observed_SHOALS_z_distr(axes[0], color='C5', lw=3, label='SHOALS observed')
axes[0].legend()
axes[0].set_title('Comparison between the z distribution of the k=0 and k=2 A models\n above\
              {:.0e} erg/cm2 using K-S tests and bootstrapping'.format(thrsh), **{'size':15})
plt.show()
# Out:
# 17:31:14.635 [INFO] Subsampling done in 30.914 s
# 17:32:16.941 [INFO] KS calculations done in 62.305 s
# 17:33:00.156 [INFO] CDF calculation done in 43.215 s

# %%
# Now we want to explore the fluence cut vs sample size plane and see what is required to discriminate
# between k=0 and k=2. We create two arrays for the fluence cuts and the sample size we reasonably expect
# can be obtained and compute the fraction of bootstrap samples that have a p-value below 0.05
# We associate this fraction with the probability of discriminating between the k=0 and k=2 scenarios at the
# 95% confidence level.
flnc_cuts = np.array([1.8e-6, 1e-6, 5.6e-7, 3.2e-7, 1.8e-7, 1e-7, 5.7e-8])
size = np.array([56, 100, 178, 316, 562, 1000, 1780])
p_discr_z = {}
p_discr_L = {}
if load_files:
    for mod in ['LN','LN2','A','A2']:
        try:
            p_discr_z[mod] = pd.read_parquet(paths_to_dir['output']+ f'/p_discr_z_{mod}').to_numpy()
            p_discr_L[mod] = pd.read_parquet(paths_to_dir['output']+ f'/p_discr_L_{mod}').to_numpy()
        except Exception:
            pass

# %%
# WARNING: long computing time (at least 10 min)
# This is for the LogNormal models
precision=500
if not load_files:
    frac = np.zeros((len(size), len(flnc_cuts)))
    k=0
    for i, j in product(range(len(size)), range(len(flnc_cuts))):
        log.info("{:.1f}% Size, fluence cut = {} {}".format(100*k/(len(size)*len(flnc_cuts)), size[i], flnc_cuts[j]))
        frac[i,j]= st.subsample_and_KS(dfs['k0_LN_nF'].properties[(dfs['k0_LN_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                         dfs['k2_LN_nF'].properties[(dfs['k2_LN_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                         key='z',
                         precision=precision,
                         bins=np.linspace(0,20,precision+1),
                         N_sub=size[i],
                         N_bs=1000,
                         subsample1=False)
        log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
        k+=1
    p_discr_z['LN'] = frac
# Out:
# 12:21:44.208 [INFO] 0.0% Size, fluence cut = 56 1.8e-06
# 12:21:45.943 [INFO] Subsampling done in 1.684 s
# 12:21:48.151 [INFO] KS calculations done in 2.207 s
# 12:21:49.523 [INFO] CDF calculation done in 1.372 s
# 12:21:49.533 [INFO] Fraction of samples different at the 95% confidence level : 0.07
# 12:21:49.533 [INFO] 2.0408163265306123% Size, fluence cut = 56 1e-06
# 12:21:51.678 [INFO] Subsampling done in 2.081 s
# 12:21:55.101 [INFO] KS calculations done in 3.423 s
# 12:21:57.380 [INFO] CDF calculation done in 2.278 s
# 12:21:57.400 [INFO] Fraction of samples different at the 95% confidence level : 0.194
# 12:21:57.400 [INFO] 4.081632653061225% Size, fluence cut = 56 5.6e-07
# 12:22:01.151 [INFO] Subsampling done in 3.679 s
# 12:22:07.109 [INFO] KS calculations done in 5.958 s
# 12:22:10.625 [INFO] CDF calculation done in 3.515 s
# 12:22:10.655 [INFO] Fraction of samples different at the 95% confidence level : 0.391
# 12:22:10.655 [INFO] 6.122448979591836% Size, fluence cut = 56 3.2e-07
# 12:22:16.580 [INFO] Subsampling done in 5.805 s
# 12:22:26.195 [INFO] KS calculations done in 9.614 s
# 12:22:32.206 [INFO] CDF calculation done in 6.010 s
# 12:22:32.249 [INFO] Fraction of samples different at the 95% confidence level : 0.565
# 12:22:32.250 [INFO] 8.16326530612245% Size, fluence cut = 56 1.8e-07
# 12:22:39.860 [INFO] Subsampling done in 7.471 s
# 12:22:53.793 [INFO] KS calculations done in 13.933 s
# 12:23:03.129 [INFO] CDF calculation done in 9.335 s
# 12:23:03.196 [INFO] Fraction of samples different at the 95% confidence level : 0.696
# 12:23:03.197 [INFO] 10.204081632653061% Size, fluence cut = 56 1e-07
# 12:23:14.541 [INFO] Subsampling done in 11.247 s
# 12:23:36.399 [INFO] KS calculations done in 21.857 s
# 12:23:49.673 [INFO] CDF calculation done in 13.274 s
# 12:23:49.788 [INFO] Fraction of samples different at the 95% confidence level : 0.822
# 12:23:49.789 [INFO] 12.244897959183673% Size, fluence cut = 56 5.7e-08
# 12:24:06.661 [INFO] Subsampling done in 16.726 s
# 12:24:35.720 [INFO] KS calculations done in 29.059 s
# 12:24:53.020 [INFO] CDF calculation done in 17.299 s
# 12:24:53.125 [INFO] Fraction of samples different at the 95% confidence level : 0.872
# 12:24:53.126 [INFO] 14.285714285714286% Size, fluence cut = 100 1.8e-06
# 12:24:54.513 [INFO] Subsampling done in 1.356 s
# 12:24:56.656 [INFO] KS calculations done in 2.142 s
# 12:24:58.096 [INFO] CDF calculation done in 1.440 s
# 12:24:58.105 [INFO] Fraction of samples different at the 95% confidence level : 0.094
# 12:24:58.106 [INFO] 16.3265306122449% Size, fluence cut = 100 1e-06
# 12:25:00.226 [INFO] Subsampling done in 2.082 s
# 12:25:04.276 [INFO] KS calculations done in 4.049 s
# 12:25:06.803 [INFO] CDF calculation done in 2.527 s
# 12:25:06.823 [INFO] Fraction of samples different at the 95% confidence level : 0.336
# 12:25:06.823 [INFO] 18.367346938775512% Size, fluence cut = 100 5.6e-07
# 12:25:10.846 [INFO] Subsampling done in 3.976 s
# 12:25:17.640 [INFO] KS calculations done in 6.793 s
# 12:25:21.897 [INFO] CDF calculation done in 4.257 s
# 12:25:21.923 [INFO] Fraction of samples different at the 95% confidence level : 0.638
# 12:25:21.924 [INFO] 20.408163265306122% Size, fluence cut = 100 3.2e-07
# 12:25:28.147 [INFO] Subsampling done in 6.166 s
# 12:25:38.425 [INFO] KS calculations done in 10.277 s
# 12:25:44.771 [INFO] CDF calculation done in 6.346 s
# 12:25:44.807 [INFO] Fraction of samples different at the 95% confidence level : 0.859
# 12:25:44.808 [INFO] 22.448979591836736% Size, fluence cut = 100 1.8e-07
# 12:25:52.442 [INFO] Subsampling done in 7.553 s
# 12:26:06.853 [INFO] KS calculations done in 14.410 s
# 12:26:16.175 [INFO] CDF calculation done in 9.322 s
# 12:26:16.227 [INFO] Fraction of samples different at the 95% confidence level : 0.948
# 12:26:16.228 [INFO] 24.489795918367346% Size, fluence cut = 100 1e-07
# 12:26:27.967 [INFO] Subsampling done in 11.661 s
# 12:26:50.936 [INFO] KS calculations done in 22.969 s
# 12:27:04.147 [INFO] CDF calculation done in 13.210 s
# 12:27:04.238 [INFO] Fraction of samples different at the 95% confidence level : 0.977
# 12:27:04.239 [INFO] 26.53061224489796% Size, fluence cut = 100 5.7e-08
# 12:27:20.759 [INFO] Subsampling done in 16.427 s
# 12:27:49.204 [INFO] KS calculations done in 28.445 s
# 12:28:06.308 [INFO] CDF calculation done in 17.103 s
# 12:28:06.406 [INFO] Fraction of samples different at the 95% confidence level : 0.997
# 12:28:06.407 [INFO] 28.571428571428573% Size, fluence cut = 178 1.8e-06
# 12:28:07.791 [INFO] Subsampling done in 1.351 s
# 12:28:10.342 [INFO] KS calculations done in 2.550 s
# 12:28:12.271 [INFO] CDF calculation done in 1.929 s
# 12:28:12.284 [INFO] Fraction of samples different at the 95% confidence level : 0.159
# 12:28:12.284 [INFO] 30.612244897959183% Size, fluence cut = 178 1e-06
# 12:28:14.618 [INFO] Subsampling done in 2.274 s
# 12:28:18.323 [INFO] KS calculations done in 3.704 s
# 12:28:20.905 [INFO] CDF calculation done in 2.582 s
# 12:28:20.926 [INFO] Fraction of samples different at the 95% confidence level : 0.572
# 12:28:20.927 [INFO] 32.6530612244898% Size, fluence cut = 178 5.6e-07
# 12:28:24.766 [INFO] Subsampling done in 3.789 s
# 12:28:31.565 [INFO] KS calculations done in 6.798 s
# 12:28:35.907 [INFO] CDF calculation done in 4.341 s
# 12:28:35.937 [INFO] Fraction of samples different at the 95% confidence level : 0.913
# 12:28:35.938 [INFO] 34.69387755102041% Size, fluence cut = 178 3.2e-07
# 12:28:41.266 [INFO] Subsampling done in 5.266 s
# 12:28:51.873 [INFO] KS calculations done in 10.607 s
# 12:28:58.437 [INFO] CDF calculation done in 6.563 s
# 12:28:58.476 [INFO] Fraction of samples different at the 95% confidence level : 0.989
# 12:28:58.476 [INFO] 36.734693877551024% Size, fluence cut = 178 1.8e-07
# 12:29:07.212 [INFO] Subsampling done in 8.665 s
# 12:29:23.051 [INFO] KS calculations done in 15.837 s
# 12:29:32.400 [INFO] CDF calculation done in 9.348 s
# 12:29:32.451 [INFO] Fraction of samples different at the 95% confidence level : 0.999
# 12:29:32.452 [INFO] 38.775510204081634% Size, fluence cut = 178 1e-07
# 12:29:44.747 [INFO] Subsampling done in 12.217 s
# 12:30:06.921 [INFO] KS calculations done in 22.174 s
# 12:30:19.810 [INFO] CDF calculation done in 12.888 s
# 12:30:19.916 [INFO] Fraction of samples different at the 95% confidence level : 0.999
# 12:30:19.917 [INFO] 40.816326530612244% Size, fluence cut = 178 5.7e-08
# 12:30:35.176 [INFO] Subsampling done in 15.120 s
# 12:31:04.345 [INFO] KS calculations done in 29.168 s
# 12:31:21.589 [INFO] CDF calculation done in 17.243 s
# 12:31:21.688 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:31:21.689 [INFO] 42.857142857142854% Size, fluence cut = 316 1.8e-06
# 12:31:23.159 [INFO] Subsampling done in 1.430 s
# 12:31:25.517 [INFO] KS calculations done in 2.357 s
# 12:31:26.988 [INFO] CDF calculation done in 1.470 s
# 12:31:27.000 [INFO] Fraction of samples different at the 95% confidence level : 0.251
# 12:31:27.001 [INFO] 44.89795918367347% Size, fluence cut = 316 1e-06
# 12:31:29.282 [INFO] Subsampling done in 2.232 s
# 12:31:33.263 [INFO] KS calculations done in 3.981 s
# 12:31:35.876 [INFO] CDF calculation done in 2.612 s
# 12:31:35.903 [INFO] Fraction of samples different at the 95% confidence level : 0.864
# 12:31:35.904 [INFO] 46.93877551020408% Size, fluence cut = 316 5.6e-07
# 12:31:39.661 [INFO] Subsampling done in 3.673 s
# 12:31:46.167 [INFO] KS calculations done in 6.505 s
# 12:31:50.347 [INFO] CDF calculation done in 4.180 s
# 12:31:50.381 [INFO] Fraction of samples different at the 95% confidence level : 0.995
# 12:31:50.382 [INFO] 48.97959183673469% Size, fluence cut = 316 3.2e-07
# 12:31:55.686 [INFO] Subsampling done in 5.231 s
# 12:32:06.859 [INFO] KS calculations done in 11.172 s
# 12:32:13.238 [INFO] CDF calculation done in 6.379 s
# 12:32:13.274 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:32:13.274 [INFO] 51.02040816326531% Size, fluence cut = 316 1.8e-07
# 12:32:20.033 [INFO] Subsampling done in 6.690 s
# 12:32:34.664 [INFO] KS calculations done in 14.630 s
# 12:32:43.340 [INFO] CDF calculation done in 8.676 s
# 12:32:43.388 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:32:43.389 [INFO] 53.06122448979592% Size, fluence cut = 316 1e-07
# 12:32:51.926 [INFO] Subsampling done in 8.460 s
# 12:33:12.783 [INFO] KS calculations done in 20.856 s
# 12:33:25.075 [INFO] CDF calculation done in 12.291 s
# 12:33:25.152 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:33:25.153 [INFO] 55.10204081632653% Size, fluence cut = 316 5.7e-08
# 12:33:36.628 [INFO] Subsampling done in 11.390 s
# 12:34:04.791 [INFO] KS calculations done in 28.162 s
# 12:34:21.593 [INFO] CDF calculation done in 16.802 s
# 12:34:21.691 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:34:21.692 [INFO] 57.142857142857146% Size, fluence cut = 562 1.8e-06
# 12:34:23.057 [INFO] Subsampling done in 1.334 s
# 12:34:25.271 [INFO] KS calculations done in 2.213 s
# 12:34:26.585 [INFO] CDF calculation done in 1.314 s
# 12:34:26.594 [INFO] Fraction of samples different at the 95% confidence level : 0.427
# 12:34:26.595 [INFO] 59.183673469387756% Size, fluence cut = 562 1e-06
# 12:34:28.685 [INFO] Subsampling done in 2.052 s
# 12:34:32.330 [INFO] KS calculations done in 3.645 s
# 12:34:34.397 [INFO] CDF calculation done in 2.066 s
# 12:34:34.416 [INFO] Fraction of samples different at the 95% confidence level : 0.991
# 12:34:34.417 [INFO] 61.224489795918366% Size, fluence cut = 562 5.6e-07
# 12:34:37.605 [INFO] Subsampling done in 3.141 s
# 12:34:43.254 [INFO] KS calculations done in 5.648 s
# 12:34:46.597 [INFO] CDF calculation done in 3.342 s
# 12:34:46.622 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:34:46.623 [INFO] 63.265306122448976% Size, fluence cut = 562 3.2e-07
# 12:34:51.050 [INFO] Subsampling done in 4.371 s
# 12:35:01.168 [INFO] KS calculations done in 10.117 s
# 12:35:06.892 [INFO] CDF calculation done in 5.723 s
# 12:35:06.928 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:35:06.929 [INFO] 65.3061224489796% Size, fluence cut = 562 1.8e-07
# 12:35:13.586 [INFO] Subsampling done in 6.589 s
# 12:35:28.033 [INFO] KS calculations done in 14.446 s
# 12:35:36.643 [INFO] CDF calculation done in 8.609 s
# 12:35:36.691 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:35:36.692 [INFO] 67.34693877551021% Size, fluence cut = 562 1e-07
# 12:35:46.005 [INFO] Subsampling done in 9.235 s
# 12:36:06.649 [INFO] KS calculations done in 20.644 s
# 12:36:18.934 [INFO] CDF calculation done in 12.284 s
# 12:36:19.012 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:36:19.012 [INFO] 69.38775510204081% Size, fluence cut = 562 5.7e-08
# 12:36:30.589 [INFO] Subsampling done in 11.487 s
# 12:36:59.365 [INFO] KS calculations done in 28.776 s
# 12:37:16.184 [INFO] CDF calculation done in 16.819 s
# 12:37:16.284 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:37:16.285 [INFO] 71.42857142857143% Size, fluence cut = 1000 1.8e-06
# 12:37:17.659 [INFO] Subsampling done in 1.344 s
# 12:37:19.931 [INFO] KS calculations done in 2.271 s
# 12:37:21.272 [INFO] CDF calculation done in 1.341 s
# 12:37:21.281 [INFO] Fraction of samples different at the 95% confidence level : 0.711
# 12:37:21.281 [INFO] 73.46938775510205% Size, fluence cut = 1000 1e-06
# 12:37:23.293 [INFO] Subsampling done in 1.974 s
# 12:37:26.937 [INFO] KS calculations done in 3.643 s
# 12:37:29.134 [INFO] CDF calculation done in 2.196 s
# 12:37:29.153 [INFO] Fraction of samples different at the 95% confidence level : 0.999
# 12:37:29.154 [INFO] 75.51020408163265% Size, fluence cut = 1000 5.6e-07
# 12:37:32.340 [INFO] Subsampling done in 3.139 s
# 12:37:37.982 [INFO] KS calculations done in 5.640 s
# 12:37:41.272 [INFO] CDF calculation done in 3.290 s
# 12:37:41.300 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:37:41.300 [INFO] 77.55102040816327% Size, fluence cut = 1000 3.2e-07
# 12:37:45.971 [INFO] Subsampling done in 4.615 s
# 12:37:55.753 [INFO] KS calculations done in 9.781 s
# 12:38:01.472 [INFO] CDF calculation done in 5.719 s
# 12:38:01.507 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:38:01.508 [INFO] 79.59183673469387% Size, fluence cut = 1000 1.8e-07
# 12:38:08.105 [INFO] Subsampling done in 6.530 s
# 12:38:23.192 [INFO] KS calculations done in 15.086 s
# 12:38:31.764 [INFO] CDF calculation done in 8.572 s
# 12:38:31.813 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:38:31.813 [INFO] 81.63265306122449% Size, fluence cut = 1000 1e-07
# 12:38:40.310 [INFO] Subsampling done in 8.419 s
# 12:39:01.593 [INFO] KS calculations done in 21.282 s
# 12:39:14.342 [INFO] CDF calculation done in 12.748 s
# 12:39:14.426 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:39:14.427 [INFO] 83.6734693877551% Size, fluence cut = 1000 5.7e-08
# 12:39:28.049 [INFO] Subsampling done in 13.526 s
# 12:39:58.590 [INFO] KS calculations done in 30.540 s
# 12:40:15.803 [INFO] CDF calculation done in 17.213 s
# 12:40:15.903 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:40:15.904 [INFO] 85.71428571428571% Size, fluence cut = 1780 1.8e-06
# 12:40:17.279 [INFO] Subsampling done in 1.344 s
# 12:40:19.677 [INFO] KS calculations done in 2.397 s
# 12:40:21.064 [INFO] CDF calculation done in 1.386 s
# 12:40:21.073 [INFO] Fraction of samples different at the 95% confidence level : 0.929
# 12:40:21.074 [INFO] 87.75510204081633% Size, fluence cut = 1780 1e-06
# 12:40:23.750 [INFO] Subsampling done in 2.637 s
# 12:40:28.738 [INFO] KS calculations done in 4.987 s
# 12:40:31.110 [INFO] CDF calculation done in 2.371 s
# 12:40:31.131 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:40:31.132 [INFO] 89.79591836734694% Size, fluence cut = 1780 5.6e-07
# 12:40:34.962 [INFO] Subsampling done in 3.780 s
# 12:40:41.232 [INFO] KS calculations done in 6.270 s
# 12:40:45.315 [INFO] CDF calculation done in 4.083 s
# 12:40:45.343 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:40:45.344 [INFO] 91.83673469387755% Size, fluence cut = 1780 3.2e-07
# 12:40:50.761 [INFO] Subsampling done in 5.360 s
# 12:41:02.760 [INFO] KS calculations done in 11.998 s
# 12:41:09.668 [INFO] CDF calculation done in 6.908 s
# 12:41:09.705 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:41:09.705 [INFO] 93.87755102040816% Size, fluence cut = 1780 1.8e-07
# 12:41:18.359 [INFO] Subsampling done in 8.584 s
# 12:41:34.563 [INFO] KS calculations done in 16.203 s
# 12:41:43.965 [INFO] CDF calculation done in 9.402 s
# 12:41:44.026 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:41:44.027 [INFO] 95.91836734693878% Size, fluence cut = 1780 1e-07
# 12:41:53.208 [INFO] Subsampling done in 9.096 s
# 12:42:15.664 [INFO] KS calculations done in 22.456 s
# 12:42:28.685 [INFO] CDF calculation done in 13.019 s
# 12:42:28.774 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 12:42:28.774 [INFO] 97.95918367346938% Size, fluence cut = 1780 5.7e-08
# 12:42:49.267 [INFO] Subsampling done in 20.396 s
# 12:43:21.937 [INFO] KS calculations done in 32.669 s
# 12:43:39.320 [INFO] CDF calculation done in 17.383 s
# 12:43:39.464 [INFO] Fraction of samples different at the 95% confidence level : 1.0

# %%
# WARNING: long computing time (at least 10 min)
# This is to check that results don't depend on whether we're subsampling from k=0 or k=2
if not load_files:
    frac = np.zeros((len(size), len(flnc_cuts)))
    k=0
    for i, j in product(range(len(size)), range(len(flnc_cuts))):
        log.info("{:.1f} %. Size, fluence cut = {} {}".format(100*k/(len(size)*len(flnc_cuts)), size[i], flnc_cuts[j]))
        frac[i,j]= st.subsample_and_KS(dfs['k0_LN_nF'].properties[(dfs['k0_LN_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                         dfs['k2_LN_nF'].properties[(dfs['k2_LN_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                         key='z',
                         precision=precision,
                         bins=np.linspace(0,20,precision+1),
                         N_sub=size[i],
                         N_bs=1000,
                         subsample2=False)
        log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
        k+=1
    p_discr_z['LN2'] = frac
# Out:
# 12:44:03.825 [INFO] 0.0 %. Size, fluence cut = 56 1.8e-06
# 12:44:04.613 [INFO] Subsampling done in 0.748 s
# 12:44:15.968 [INFO] KS calculations done in 11.355 s
# 12:44:23.100 [INFO] CDF calculation done in 7.131 s
# 12:44:23.136 [INFO] Fraction of samples different at the 95% confidence level : 0.086
# 12:44:23.137 [INFO] 2.0 %. Size, fluence cut = 56 1e-06
# 12:44:24.341 [INFO] Subsampling done in 1.143 s
# 12:44:43.717 [INFO] KS calculations done in 19.376 s
# 12:44:55.229 [INFO] CDF calculation done in 11.511 s
# 12:44:55.286 [INFO] Fraction of samples different at the 95% confidence level : 0.206
# 12:44:55.286 [INFO] 4.1 %. Size, fluence cut = 56 5.6e-07
# 12:44:56.867 [INFO] Subsampling done in 1.518 s
# 12:45:26.001 [INFO] KS calculations done in 29.133 s
# 12:45:42.652 [INFO] CDF calculation done in 16.651 s
# 12:45:42.724 [INFO] Fraction of samples different at the 95% confidence level : 0.403
# 12:45:42.725 [INFO] 6.1 %. Size, fluence cut = 56 3.2e-07
# 12:45:44.906 [INFO] Subsampling done in 2.120 s
# 12:46:26.547 [INFO] KS calculations done in 41.641 s
# 12:46:51.639 [INFO] CDF calculation done in 25.091 s
# 12:46:51.774 [INFO] Fraction of samples different at the 95% confidence level : 0.544
# 12:46:51.775 [INFO] 8.2 %. Size, fluence cut = 56 1.8e-07
# 12:46:55.155 [INFO] Subsampling done in 3.306 s
# 12:47:53.497 [INFO] KS calculations done in 58.341 s
# 12:48:28.109 [INFO] CDF calculation done in 34.611 s
# 12:48:28.271 [INFO] Fraction of samples different at the 95% confidence level : 0.695
# 12:48:28.272 [INFO] 10.2 %. Size, fluence cut = 56 1e-07
# 12:48:32.631 [INFO] Subsampling done in 4.275 s
# 12:49:49.838 [INFO] KS calculations done in 77.207 s
# 12:50:35.186 [INFO] CDF calculation done in 45.347 s
# 12:50:35.437 [INFO] Fraction of samples different at the 95% confidence level : 0.77
# 12:50:35.437 [INFO] 12.2 %. Size, fluence cut = 56 5.7e-08
# 12:50:41.607 [INFO] Subsampling done in 6.078 s
# 12:52:19.304 [INFO] KS calculations done in 97.696 s
# 12:53:17.780 [INFO] CDF calculation done in 58.475 s
# 12:53:18.158 [INFO] Fraction of samples different at the 95% confidence level : 0.845
# 12:53:18.159 [INFO] 14.3 %. Size, fluence cut = 100 1.8e-06
# 12:53:18.916 [INFO] Subsampling done in 0.714 s
# 12:53:31.341 [INFO] KS calculations done in 12.424 s
# 12:53:38.703 [INFO] CDF calculation done in 7.361 s
# 12:53:38.731 [INFO] Fraction of samples different at the 95% confidence level : 0.108
# 12:53:38.731 [INFO] 16.3 %. Size, fluence cut = 100 1e-06
# 12:53:39.758 [INFO] Subsampling done in 0.984 s
# 12:53:58.007 [INFO] KS calculations done in 18.249 s
# 12:54:09.501 [INFO] CDF calculation done in 11.493 s
# 12:54:09.545 [INFO] Fraction of samples different at the 95% confidence level : 0.356
# 12:54:09.545 [INFO] 18.4 %. Size, fluence cut = 100 5.6e-07
# 12:54:11.265 [INFO] Subsampling done in 1.672 s
# 12:54:39.830 [INFO] KS calculations done in 28.565 s
# 12:54:57.377 [INFO] CDF calculation done in 17.546 s
# 12:54:57.446 [INFO] Fraction of samples different at the 95% confidence level : 0.638
# 12:54:57.446 [INFO] 20.4 %. Size, fluence cut = 100 3.2e-07
# 12:54:59.854 [INFO] Subsampling done in 2.312 s
# 12:55:44.180 [INFO] KS calculations done in 44.325 s
# 12:56:09.388 [INFO] CDF calculation done in 25.207 s
# 12:56:09.512 [INFO] Fraction of samples different at the 95% confidence level : 0.801
# 12:56:09.513 [INFO] 22.4 %. Size, fluence cut = 100 1.8e-07
# 12:56:12.897 [INFO] Subsampling done in 3.244 s
# 12:57:12.082 [INFO] KS calculations done in 59.184 s
# 12:57:47.073 [INFO] CDF calculation done in 34.991 s
# 12:57:47.313 [INFO] Fraction of samples different at the 95% confidence level : 0.913
# 12:57:47.314 [INFO] 24.5 %. Size, fluence cut = 100 1e-07
# 12:57:52.773 [INFO] Subsampling done in 5.355 s
# 12:59:13.928 [INFO] KS calculations done in 81.154 s
# 12:59:59.555 [INFO] CDF calculation done in 45.625 s
# 12:59:59.898 [INFO] Fraction of samples different at the 95% confidence level : 0.962
# 12:59:59.899 [INFO] 26.5 %. Size, fluence cut = 100 5.7e-08
# 13:00:07.360 [INFO] Subsampling done in 7.288 s
# 13:01:43.966 [INFO] KS calculations done in 96.606 s
# 13:02:39.822 [INFO] CDF calculation done in 55.854 s
# 13:02:40.138 [INFO] Fraction of samples different at the 95% confidence level : 0.974
# 13:02:40.139 [INFO] 28.6 %. Size, fluence cut = 178 1.8e-06
# 13:02:40.852 [INFO] Subsampling done in 0.681 s
# 13:02:51.828 [INFO] KS calculations done in 10.975 s
# 13:02:58.814 [INFO] CDF calculation done in 6.986 s
# 13:02:58.848 [INFO] Fraction of samples different at the 95% confidence level : 0.156
# 13:02:58.849 [INFO] 30.6 %. Size, fluence cut = 178 1e-06
# 13:02:59.964 [INFO] Subsampling done in 1.062 s
# 13:03:18.463 [INFO] KS calculations done in 18.498 s
# 13:03:29.407 [INFO] CDF calculation done in 10.943 s
# 13:03:29.451 [INFO] Fraction of samples different at the 95% confidence level : 0.575
# 13:03:29.452 [INFO] 32.7 %. Size, fluence cut = 178 5.6e-07
# 13:03:30.952 [INFO] Subsampling done in 1.444 s
# 13:03:58.467 [INFO] KS calculations done in 27.514 s
# 13:04:15.118 [INFO] CDF calculation done in 16.650 s
# 13:04:15.188 [INFO] Fraction of samples different at the 95% confidence level : 0.884
# 13:04:15.189 [INFO] 34.7 %. Size, fluence cut = 178 3.2e-07
# 13:04:17.321 [INFO] Subsampling done in 2.062 s
# 13:04:57.759 [INFO] KS calculations done in 40.437 s
# 13:05:21.410 [INFO] CDF calculation done in 23.650 s
# 13:05:21.530 [INFO] Fraction of samples different at the 95% confidence level : 0.972
# 13:05:21.531 [INFO] 36.7 %. Size, fluence cut = 178 1.8e-07
# 13:05:24.725 [INFO] Subsampling done in 3.113 s
# 13:06:21.310 [INFO] KS calculations done in 56.585 s
# 13:06:54.602 [INFO] CDF calculation done in 33.291 s
# 13:06:54.755 [INFO] Fraction of samples different at the 95% confidence level : 0.998
# 13:06:54.755 [INFO] 38.8 %. Size, fluence cut = 178 1e-07
# 13:06:58.926 [INFO] Subsampling done in 4.089 s
# 13:08:14.479 [INFO] KS calculations done in 75.552 s
# 13:08:59.160 [INFO] CDF calculation done in 44.681 s
# 13:08:59.383 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:08:59.384 [INFO] 40.8 %. Size, fluence cut = 178 5.7e-08
# 13:09:05.199 [INFO] Subsampling done in 5.725 s
# 13:10:37.701 [INFO] KS calculations done in 92.501 s
# 13:11:32.777 [INFO] CDF calculation done in 55.076 s
# 13:11:33.060 [INFO] Fraction of samples different at the 95% confidence level : 0.999
# 13:11:33.061 [INFO] 42.9 %. Size, fluence cut = 316 1.8e-06
# 13:11:33.773 [INFO] Subsampling done in 0.677 s
# 13:11:44.901 [INFO] KS calculations done in 11.127 s
# 13:11:51.390 [INFO] CDF calculation done in 6.488 s
# 13:11:51.417 [INFO] Fraction of samples different at the 95% confidence level : 0.265
# 13:11:51.417 [INFO] 44.9 %. Size, fluence cut = 316 1e-06
# 13:11:52.457 [INFO] Subsampling done in 0.997 s
# 13:12:11.338 [INFO] KS calculations done in 18.880 s
# 13:12:22.380 [INFO] CDF calculation done in 11.042 s
# 13:12:22.432 [INFO] Fraction of samples different at the 95% confidence level : 0.849
# 13:12:22.433 [INFO] 46.9 %. Size, fluence cut = 316 5.6e-07
# 13:12:23.971 [INFO] Subsampling done in 1.487 s
# 13:12:52.316 [INFO] KS calculations done in 28.344 s
# 13:13:08.911 [INFO] CDF calculation done in 16.594 s
# 13:13:08.980 [INFO] Fraction of samples different at the 95% confidence level : 0.99
# 13:13:08.980 [INFO] 49.0 %. Size, fluence cut = 316 3.2e-07
# 13:13:11.161 [INFO] Subsampling done in 2.124 s
# 13:13:51.877 [INFO] KS calculations done in 40.715 s
# 13:14:15.449 [INFO] CDF calculation done in 23.572 s
# 13:14:15.554 [INFO] Fraction of samples different at the 95% confidence level : 0.999
# 13:14:15.555 [INFO] 51.0 %. Size, fluence cut = 316 1.8e-07
# 13:14:18.589 [INFO] Subsampling done in 2.964 s
# 13:15:15.234 [INFO] KS calculations done in 56.644 s
# 13:15:48.467 [INFO] CDF calculation done in 33.232 s
# 13:15:48.621 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:15:48.622 [INFO] 53.1 %. Size, fluence cut = 316 1e-07
# 13:15:52.702 [INFO] Subsampling done in 4.002 s
# 13:17:07.012 [INFO] KS calculations done in 74.308 s
# 13:17:51.116 [INFO] CDF calculation done in 44.104 s
# 13:17:51.340 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:17:51.341 [INFO] 55.1 %. Size, fluence cut = 316 5.7e-08
# 13:17:56.845 [INFO] Subsampling done in 5.416 s
# 13:19:29.612 [INFO] KS calculations done in 92.766 s
# 13:20:24.535 [INFO] CDF calculation done in 54.922 s
# 13:20:24.812 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:20:24.813 [INFO] 57.1 %. Size, fluence cut = 562 1.8e-06
# 13:20:25.495 [INFO] Subsampling done in 0.650 s
# 13:20:36.764 [INFO] KS calculations done in 11.268 s
# 13:20:43.152 [INFO] CDF calculation done in 6.388 s
# 13:20:43.178 [INFO] Fraction of samples different at the 95% confidence level : 0.456
# 13:20:43.179 [INFO] 59.2 %. Size, fluence cut = 562 1e-06
# 13:20:44.181 [INFO] Subsampling done in 0.963 s
# 13:21:02.501 [INFO] KS calculations done in 18.320 s
# 13:21:13.458 [INFO] CDF calculation done in 10.956 s
# 13:21:13.502 [INFO] Fraction of samples different at the 95% confidence level : 0.986
# 13:21:13.503 [INFO] 61.2 %. Size, fluence cut = 562 5.6e-07
# 13:21:15.058 [INFO] Subsampling done in 1.508 s
# 13:21:43.397 [INFO] KS calculations done in 28.338 s
# 13:21:59.995 [INFO] CDF calculation done in 16.598 s
# 13:22:00.061 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:22:00.062 [INFO] 63.3 %. Size, fluence cut = 562 3.2e-07
# 13:22:02.187 [INFO] Subsampling done in 2.068 s
# 13:22:43.357 [INFO] KS calculations done in 41.169 s
# 13:23:06.948 [INFO] CDF calculation done in 23.590 s
# 13:23:07.049 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:23:07.050 [INFO] 65.3 %. Size, fluence cut = 562 1.8e-07
# 13:23:10.097 [INFO] Subsampling done in 2.980 s
# 13:24:07.365 [INFO] KS calculations done in 57.267 s
# 13:24:40.516 [INFO] CDF calculation done in 33.151 s
# 13:24:40.668 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:24:40.668 [INFO] 67.3 %. Size, fluence cut = 562 1e-07
# 13:24:44.825 [INFO] Subsampling done in 4.080 s
# 13:26:00.165 [INFO] KS calculations done in 75.339 s
# 13:26:44.271 [INFO] CDF calculation done in 44.105 s
# 13:26:44.489 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:26:44.490 [INFO] 69.4 %. Size, fluence cut = 562 5.7e-08
# 13:26:49.971 [INFO] Subsampling done in 5.394 s
# 13:28:23.666 [INFO] KS calculations done in 93.694 s
# 13:29:18.636 [INFO] CDF calculation done in 54.969 s
# 13:29:18.908 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:29:18.909 [INFO] 71.4 %. Size, fluence cut = 1000 1.8e-06
# 13:29:19.599 [INFO] Subsampling done in 0.659 s
# 13:29:31.064 [INFO] KS calculations done in 11.465 s
# 13:29:37.450 [INFO] CDF calculation done in 6.385 s
# 13:29:37.477 [INFO] Fraction of samples different at the 95% confidence level : 0.704
# 13:29:37.477 [INFO] 73.5 %. Size, fluence cut = 1000 1e-06
# 13:29:38.478 [INFO] Subsampling done in 0.963 s
# 13:29:57.205 [INFO] KS calculations done in 18.726 s
# 13:30:08.148 [INFO] CDF calculation done in 10.943 s
# 13:30:08.192 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:30:08.192 [INFO] 75.5 %. Size, fluence cut = 1000 5.6e-07
# 13:30:09.734 [INFO] Subsampling done in 1.495 s
# 13:30:38.466 [INFO] KS calculations done in 28.732 s
# 13:30:55.067 [INFO] CDF calculation done in 16.599 s
# 13:30:55.131 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:30:55.132 [INFO] 77.6 %. Size, fluence cut = 1000 3.2e-07
# 13:30:57.267 [INFO] Subsampling done in 2.077 s
# 13:31:38.982 [INFO] KS calculations done in 41.714 s
# 13:32:02.603 [INFO] CDF calculation done in 23.620 s
# 13:32:02.701 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:32:02.702 [INFO] 79.6 %. Size, fluence cut = 1000 1.8e-07
# 13:32:05.776 [INFO] Subsampling done in 3.007 s
# 13:33:03.880 [INFO] KS calculations done in 58.103 s
# 13:33:37.128 [INFO] CDF calculation done in 33.248 s
# 13:33:37.276 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:33:37.276 [INFO] 81.6 %. Size, fluence cut = 1000 1e-07
# 13:33:41.338 [INFO] Subsampling done in 3.985 s
# 13:34:59.580 [INFO] KS calculations done in 78.242 s
# 13:35:46.156 [INFO] CDF calculation done in 46.575 s
# 13:35:46.419 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:35:46.420 [INFO] 83.7 %. Size, fluence cut = 1000 5.7e-08
# 13:35:53.450 [INFO] Subsampling done in 6.904 s
# 13:37:38.804 [INFO] KS calculations done in 105.353 s
# 13:38:36.842 [INFO] CDF calculation done in 58.037 s
# 13:38:37.114 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:38:37.115 [INFO] 85.7 %. Size, fluence cut = 1780 1.8e-06
# 13:38:37.876 [INFO] Subsampling done in 0.663 s
# 13:38:49.588 [INFO] KS calculations done in 11.711 s
# 13:38:56.043 [INFO] CDF calculation done in 6.454 s
# 13:38:56.071 [INFO] Fraction of samples different at the 95% confidence level : 0.935
# 13:38:56.072 [INFO] 87.8 %. Size, fluence cut = 1780 1e-06
# 13:38:57.077 [INFO] Subsampling done in 0.962 s
# 13:39:16.390 [INFO] KS calculations done in 19.312 s
# 13:39:27.426 [INFO] CDF calculation done in 11.036 s
# 13:39:27.471 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:39:27.472 [INFO] 89.8 %. Size, fluence cut = 1780 5.6e-07
# 13:39:28.992 [INFO] Subsampling done in 1.470 s
# 13:39:58.260 [INFO] KS calculations done in 29.268 s
# 13:40:15.337 [INFO] CDF calculation done in 17.076 s
# 13:40:15.408 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:40:15.409 [INFO] 91.8 %. Size, fluence cut = 1780 3.2e-07
# 13:40:17.625 [INFO] Subsampling done in 2.107 s
# 13:41:01.382 [INFO] KS calculations done in 43.756 s
# 13:41:24.714 [INFO] CDF calculation done in 23.332 s
# 13:41:24.824 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:41:24.825 [INFO] 93.9 %. Size, fluence cut = 1780 1.8e-07
# 13:41:28.489 [INFO] Subsampling done in 3.524 s
# 13:42:30.493 [INFO] KS calculations done in 62.003 s
# 13:43:04.295 [INFO] CDF calculation done in 33.801 s
# 13:43:04.441 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:43:04.442 [INFO] 95.9 %. Size, fluence cut = 1780 1e-07
# 13:43:08.578 [INFO] Subsampling done in 4.057 s
# 13:44:29.527 [INFO] KS calculations done in 80.948 s
# 13:45:14.669 [INFO] CDF calculation done in 45.141 s
# 13:45:14.877 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 13:45:14.878 [INFO] 98.0 %. Size, fluence cut = 1780 5.7e-08
# 13:45:20.400 [INFO] Subsampling done in 5.435 s
# 13:47:01.468 [INFO] KS calculations done in 101.067 s
# 13:47:57.265 [INFO] CDF calculation done in 55.797 s
# 13:47:57.554 [INFO] Fraction of samples different at the 95% confidence level : 1.0

# %%
# WARNING: long computing time (at least 10 min)
# Same thing with Amati-like scenarios
if not load_files:
    frac = np.zeros((len(size), len(flnc_cuts)))
    k=0
    for i, j in product(range(len(size)), range(len(flnc_cuts))):
        log.info("{:.1f} %. Size, fluence cut = {} {}".format(100*k/(len(size)*len(flnc_cuts)), size[i], flnc_cuts[j]))
        frac[i,j]= st.subsample_and_KS(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                                     dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                                     key='z',
                                     precision=precision,
                                     bins=np.linspace(0,20,precision+1),
                                     N_sub=size[i],
                                     N_bs=1000,
                                     subsample1=False)
        log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
        k+=1
    p_discr_z['A2'] = frac
# Out:
# 13:47:57.569 [INFO] 0.0 %. Size, fluence cut = 56 1.8e-06
# 13:47:59.111 [INFO] Subsampling done in 1.454 s
# 13:48:01.553 [INFO] KS calculations done in 2.441 s
# 13:48:03.115 [INFO] CDF calculation done in 1.561 s
# 13:48:03.128 [INFO] Fraction of samples different at the 95% confidence level : 0.049
# 13:48:03.129 [INFO] 2.0 %. Size, fluence cut = 56 1e-06
# 13:48:05.335 [INFO] Subsampling done in 2.165 s
# 13:48:09.219 [INFO] KS calculations done in 3.884 s
# 13:48:11.610 [INFO] CDF calculation done in 2.390 s
# 13:48:11.629 [INFO] Fraction of samples different at the 95% confidence level : 0.066
# 13:48:11.630 [INFO] 4.1 %. Size, fluence cut = 56 5.6e-07
# 13:48:15.322 [INFO] Subsampling done in 3.640 s
# 13:48:23.113 [INFO] KS calculations done in 7.790 s
# 13:48:27.729 [INFO] CDF calculation done in 4.615 s
# 13:48:27.757 [INFO] Fraction of samples different at the 95% confidence level : 0.086
# 13:48:27.758 [INFO] 6.1 %. Size, fluence cut = 56 3.2e-07
# 13:48:32.983 [INFO] Subsampling done in 5.164 s
# 13:48:44.335 [INFO] KS calculations done in 11.352 s
# 13:48:51.355 [INFO] CDF calculation done in 7.019 s
# 13:48:51.387 [INFO] Fraction of samples different at the 95% confidence level : 0.123
# 13:48:51.388 [INFO] 8.2 %. Size, fluence cut = 56 1.8e-07
# 13:48:59.449 [INFO] Subsampling done in 7.939 s
# 13:49:16.648 [INFO] KS calculations done in 17.198 s
# 13:49:27.311 [INFO] CDF calculation done in 10.662 s
# 13:49:27.372 [INFO] Fraction of samples different at the 95% confidence level : 0.153
# 13:49:27.373 [INFO] 10.2 %. Size, fluence cut = 56 1e-07
# 13:49:38.247 [INFO] Subsampling done in 10.787 s
# 13:50:02.895 [INFO] KS calculations done in 24.647 s
# 13:50:18.037 [INFO] CDF calculation done in 15.141 s
# 13:50:18.108 [INFO] Fraction of samples different at the 95% confidence level : 0.127
# 13:50:18.109 [INFO] 12.2 %. Size, fluence cut = 56 5.7e-08
# 13:50:36.085 [INFO] Subsampling done in 17.855 s
# 13:51:10.020 [INFO] KS calculations done in 33.935 s
# 13:51:30.600 [INFO] CDF calculation done in 20.579 s
# 13:51:30.702 [INFO] Fraction of samples different at the 95% confidence level : 0.139
# 13:51:30.703 [INFO] 14.3 %. Size, fluence cut = 100 1.8e-06
# 13:51:32.170 [INFO] Subsampling done in 1.435 s
# 13:51:34.645 [INFO] KS calculations done in 2.474 s
# 13:51:36.163 [INFO] CDF calculation done in 1.518 s
# 13:51:36.178 [INFO] Fraction of samples different at the 95% confidence level : 0.048
# 13:51:36.179 [INFO] 16.3 %. Size, fluence cut = 100 1e-06
# 13:51:38.374 [INFO] Subsampling done in 2.154 s
# 13:51:42.558 [INFO] KS calculations done in 4.184 s
# 13:51:45.065 [INFO] CDF calculation done in 2.506 s
# 13:51:45.084 [INFO] Fraction of samples different at the 95% confidence level : 0.093
# 13:51:45.084 [INFO] 18.4 %. Size, fluence cut = 100 5.6e-07
# 13:51:48.757 [INFO] Subsampling done in 3.622 s
# 13:51:56.209 [INFO] KS calculations done in 7.452 s
# 13:52:01.153 [INFO] CDF calculation done in 4.944 s
# 13:52:01.178 [INFO] Fraction of samples different at the 95% confidence level : 0.145
# 13:52:01.178 [INFO] 20.4 %. Size, fluence cut = 100 3.2e-07
# 13:52:07.223 [INFO] Subsampling done in 5.982 s
# 13:52:19.399 [INFO] KS calculations done in 12.175 s
# 13:52:26.798 [INFO] CDF calculation done in 7.399 s
# 13:52:26.834 [INFO] Fraction of samples different at the 95% confidence level : 0.192
# 13:52:26.835 [INFO] 22.4 %. Size, fluence cut = 100 1.8e-07
# 13:52:37.531 [INFO] Subsampling done in 10.619 s
# 13:52:55.385 [INFO] KS calculations done in 17.853 s
# 13:53:05.947 [INFO] CDF calculation done in 10.562 s
# 13:53:05.996 [INFO] Fraction of samples different at the 95% confidence level : 0.23
# 13:53:05.997 [INFO] 24.5 %. Size, fluence cut = 100 1e-07
# 13:53:17.282 [INFO] Subsampling done in 11.199 s
# 13:53:43.013 [INFO] KS calculations done in 25.730 s
# 13:53:58.490 [INFO] CDF calculation done in 15.476 s
# 13:53:58.563 [INFO] Fraction of samples different at the 95% confidence level : 0.233
# 13:53:58.564 [INFO] 26.5 %. Size, fluence cut = 100 5.7e-08
# 13:54:13.802 [INFO] Subsampling done in 15.150 s
# 13:54:48.085 [INFO] KS calculations done in 34.282 s
# 13:55:08.672 [INFO] CDF calculation done in 20.586 s
# 13:55:08.766 [INFO] Fraction of samples different at the 95% confidence level : 0.231
# 13:55:08.767 [INFO] 28.6 %. Size, fluence cut = 178 1.8e-06
# 13:55:10.248 [INFO] Subsampling done in 1.449 s
# 13:55:13.163 [INFO] KS calculations done in 2.914 s
# 13:55:14.957 [INFO] CDF calculation done in 1.793 s
# 13:55:14.973 [INFO] Fraction of samples different at the 95% confidence level : 0.052
# 13:55:14.973 [INFO] 30.6 %. Size, fluence cut = 178 1e-06
# 13:55:17.224 [INFO] Subsampling done in 2.206 s
# 13:55:22.258 [INFO] KS calculations done in 5.034 s
# 13:55:25.012 [INFO] CDF calculation done in 2.754 s
# 13:55:25.032 [INFO] Fraction of samples different at the 95% confidence level : 0.117
# 13:55:25.032 [INFO] 32.7 %. Size, fluence cut = 178 5.6e-07
# 13:55:28.612 [INFO] Subsampling done in 3.528 s
# 13:55:35.969 [INFO] KS calculations done in 7.357 s
# 13:55:40.808 [INFO] CDF calculation done in 4.839 s
# 13:55:40.831 [INFO] Fraction of samples different at the 95% confidence level : 0.194
# 13:55:40.832 [INFO] 34.7 %. Size, fluence cut = 178 3.2e-07
# 13:55:46.148 [INFO] Subsampling done in 5.255 s
# 13:55:57.449 [INFO] KS calculations done in 11.300 s
# 13:56:04.215 [INFO] CDF calculation done in 6.766 s
# 13:56:04.248 [INFO] Fraction of samples different at the 95% confidence level : 0.309
# 13:56:04.249 [INFO] 36.7 %. Size, fluence cut = 178 1.8e-07
# 13:56:11.614 [INFO] Subsampling done in 7.293 s
# 13:56:29.652 [INFO] KS calculations done in 18.037 s
# 13:56:40.226 [INFO] CDF calculation done in 10.573 s
# 13:56:40.273 [INFO] Fraction of samples different at the 95% confidence level : 0.413
# 13:56:40.274 [INFO] 38.8 %. Size, fluence cut = 178 1e-07
# 13:56:52.199 [INFO] Subsampling done in 11.843 s
# 13:57:17.035 [INFO] KS calculations done in 24.835 s
# 13:57:32.473 [INFO] CDF calculation done in 15.438 s
# 13:57:32.544 [INFO] Fraction of samples different at the 95% confidence level : 0.422
# 13:57:32.545 [INFO] 40.8 %. Size, fluence cut = 178 5.7e-08
# 13:57:47.468 [INFO] Subsampling done in 14.827 s
# 13:58:21.293 [INFO] KS calculations done in 33.825 s
# 13:58:41.518 [INFO] CDF calculation done in 20.224 s
# 13:58:41.618 [INFO] Fraction of samples different at the 95% confidence level : 0.438
# 13:58:41.619 [INFO] 42.9 %. Size, fluence cut = 316 1.8e-06
# 13:58:43.153 [INFO] Subsampling done in 1.502 s
# 13:58:45.708 [INFO] KS calculations done in 2.554 s
# 13:58:47.236 [INFO] CDF calculation done in 1.528 s
# 13:58:47.251 [INFO] Fraction of samples different at the 95% confidence level : 0.063
# 13:58:47.252 [INFO] 44.9 %. Size, fluence cut = 316 1e-06
# 13:58:49.462 [INFO] Subsampling done in 2.168 s
# 13:58:53.657 [INFO] KS calculations done in 4.194 s
# 13:58:56.123 [INFO] CDF calculation done in 2.465 s
# 13:58:56.142 [INFO] Fraction of samples different at the 95% confidence level : 0.177
# 13:58:56.143 [INFO] 46.9 %. Size, fluence cut = 316 5.6e-07
# 13:58:59.735 [INFO] Subsampling done in 3.542 s
# 13:59:07.350 [INFO] KS calculations done in 7.615 s
# 13:59:11.786 [INFO] CDF calculation done in 4.435 s
# 13:59:11.809 [INFO] Fraction of samples different at the 95% confidence level : 0.389
# 13:59:11.810 [INFO] 49.0 %. Size, fluence cut = 316 3.2e-07
# 13:59:17.553 [INFO] Subsampling done in 5.681 s
# 13:59:29.603 [INFO] KS calculations done in 12.050 s
# 13:59:36.893 [INFO] CDF calculation done in 7.289 s
# 13:59:36.925 [INFO] Fraction of samples different at the 95% confidence level : 0.551
# 13:59:36.926 [INFO] 51.0 %. Size, fluence cut = 316 1.8e-07
# 13:59:45.674 [INFO] Subsampling done in 8.676 s
# 14:00:03.121 [INFO] KS calculations done in 17.446 s
# 14:00:13.657 [INFO] CDF calculation done in 10.535 s
# 14:00:13.704 [INFO] Fraction of samples different at the 95% confidence level : 0.662
# 14:00:13.705 [INFO] 53.1 %. Size, fluence cut = 316 1e-07
# 14:00:26.402 [INFO] Subsampling done in 12.615 s
# 14:00:52.866 [INFO] KS calculations done in 26.463 s
# 14:01:08.186 [INFO] CDF calculation done in 15.320 s
# 14:01:08.261 [INFO] Fraction of samples different at the 95% confidence level : 0.709
# 14:01:08.261 [INFO] 55.1 %. Size, fluence cut = 316 5.7e-08
# 14:01:22.250 [INFO] Subsampling done in 13.895 s
# 14:01:57.101 [INFO] KS calculations done in 34.850 s
# 14:02:17.289 [INFO] CDF calculation done in 20.187 s
# 14:02:17.388 [INFO] Fraction of samples different at the 95% confidence level : 0.734
# 14:02:17.389 [INFO] 57.1 %. Size, fluence cut = 562 1.8e-06
# 14:02:18.840 [INFO] Subsampling done in 1.417 s
# 14:02:21.419 [INFO] KS calculations done in 2.578 s
# 14:02:22.954 [INFO] CDF calculation done in 1.534 s
# 14:02:22.971 [INFO] Fraction of samples different at the 95% confidence level : 0.07
# 14:02:22.972 [INFO] 59.2 %. Size, fluence cut = 562 1e-06
# 14:02:25.153 [INFO] Subsampling done in 2.140 s
# 14:02:29.414 [INFO] KS calculations done in 4.260 s
# 14:02:31.923 [INFO] CDF calculation done in 2.509 s
# 14:02:31.942 [INFO] Fraction of samples different at the 95% confidence level : 0.316
# 14:02:31.943 [INFO] 61.2 %. Size, fluence cut = 562 5.6e-07
# 14:02:35.395 [INFO] Subsampling done in 3.403 s
# 14:02:42.536 [INFO] KS calculations done in 7.141 s
# 14:02:47.878 [INFO] CDF calculation done in 5.341 s
# 14:02:47.911 [INFO] Fraction of samples different at the 95% confidence level : 0.614
# 14:02:47.911 [INFO] 63.3 %. Size, fluence cut = 562 3.2e-07
# 14:02:55.445 [INFO] Subsampling done in 7.442 s
# 14:03:07.797 [INFO] KS calculations done in 12.351 s
# 14:03:14.622 [INFO] CDF calculation done in 6.824 s
# 14:03:14.658 [INFO] Fraction of samples different at the 95% confidence level : 0.807
# 14:03:14.659 [INFO] 65.3 %. Size, fluence cut = 562 1.8e-07
# 14:03:21.994 [INFO] Subsampling done in 7.264 s
# 14:03:39.720 [INFO] KS calculations done in 17.725 s
# 14:03:50.079 [INFO] CDF calculation done in 10.359 s
# 14:03:50.127 [INFO] Fraction of samples different at the 95% confidence level : 0.889
# 14:03:50.128 [INFO] 67.3 %. Size, fluence cut = 562 1e-07
# 14:04:00.255 [INFO] Subsampling done in 10.046 s
# 14:04:25.692 [INFO] KS calculations done in 25.436 s
# 14:04:41.139 [INFO] CDF calculation done in 15.446 s
# 14:04:41.221 [INFO] Fraction of samples different at the 95% confidence level : 0.933
# 14:04:41.222 [INFO] 69.4 %. Size, fluence cut = 562 5.7e-08
# 14:04:59.350 [INFO] Subsampling done in 18.026 s
# 14:05:34.520 [INFO] KS calculations done in 35.170 s
# 14:05:54.442 [INFO] CDF calculation done in 19.921 s
# 14:05:54.550 [INFO] Fraction of samples different at the 95% confidence level : 0.937
# 14:05:54.551 [INFO] 71.4 %. Size, fluence cut = 1000 1.8e-06
# 14:05:56.047 [INFO] Subsampling done in 1.462 s
# 14:05:58.885 [INFO] KS calculations done in 2.837 s
# 14:06:00.459 [INFO] CDF calculation done in 1.573 s
# 14:06:00.473 [INFO] Fraction of samples different at the 95% confidence level : 0.078
# 14:06:00.474 [INFO] 73.5 %. Size, fluence cut = 1000 1e-06
# 14:06:02.672 [INFO] Subsampling done in 2.156 s
# 14:06:07.007 [INFO] KS calculations done in 4.334 s
# 14:06:09.454 [INFO] CDF calculation done in 2.446 s
# 14:06:09.472 [INFO] Fraction of samples different at the 95% confidence level : 0.499
# 14:06:09.473 [INFO] 75.5 %. Size, fluence cut = 1000 5.6e-07
# 14:06:13.087 [INFO] Subsampling done in 3.562 s
# 14:06:20.383 [INFO] KS calculations done in 7.295 s
# 14:06:25.052 [INFO] CDF calculation done in 4.668 s
# 14:06:25.076 [INFO] Fraction of samples different at the 95% confidence level : 0.886
# 14:06:25.077 [INFO] 77.6 %. Size, fluence cut = 1000 3.2e-07
# 14:06:31.744 [INFO] Subsampling done in 6.593 s
# 14:06:44.676 [INFO] KS calculations done in 12.931 s
# 14:06:52.459 [INFO] CDF calculation done in 7.782 s
# 14:06:52.495 [INFO] Fraction of samples different at the 95% confidence level : 0.981
# 14:06:52.496 [INFO] 79.6 %. Size, fluence cut = 1000 1.8e-07
# 14:07:02.710 [INFO] Subsampling done in 10.141 s
# 14:07:21.935 [INFO] KS calculations done in 19.224 s
# 14:07:32.692 [INFO] CDF calculation done in 10.756 s
# 14:07:32.745 [INFO] Fraction of samples different at the 95% confidence level : 0.996
# 14:07:32.746 [INFO] 81.6 %. Size, fluence cut = 1000 1e-07
# 14:07:43.164 [INFO] Subsampling done in 10.333 s
# 14:08:08.630 [INFO] KS calculations done in 25.466 s
# 14:08:23.482 [INFO] CDF calculation done in 14.851 s
# 14:08:23.568 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 14:08:23.569 [INFO] 83.7 %. Size, fluence cut = 1000 5.7e-08
# 14:08:39.261 [INFO] Subsampling done in 15.598 s
# 14:09:15.525 [INFO] KS calculations done in 36.264 s
# 14:09:36.012 [INFO] CDF calculation done in 20.486 s
# 14:09:36.123 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 14:09:36.123 [INFO] 85.7 %. Size, fluence cut = 1780 1.8e-06
# 14:09:37.680 [INFO] Subsampling done in 1.523 s
# 14:09:41.061 [INFO] KS calculations done in 3.381 s
# 14:09:42.941 [INFO] CDF calculation done in 1.880 s
# 14:09:42.957 [INFO] Fraction of samples different at the 95% confidence level : 0.115
# 14:09:42.957 [INFO] 87.8 %. Size, fluence cut = 1780 1e-06
# 14:09:45.242 [INFO] Subsampling done in 2.242 s
# 14:09:50.295 [INFO] KS calculations done in 5.053 s
# 14:09:53.127 [INFO] CDF calculation done in 2.831 s
# 14:09:53.148 [INFO] Fraction of samples different at the 95% confidence level : 0.744
# 14:09:53.149 [INFO] 89.8 %. Size, fluence cut = 1780 5.6e-07
# 14:09:56.854 [INFO] Subsampling done in 3.653 s
# 14:10:05.398 [INFO] KS calculations done in 8.543 s
# 14:10:10.213 [INFO] CDF calculation done in 4.815 s
# 14:10:10.239 [INFO] Fraction of samples different at the 95% confidence level : 0.993
# 14:10:10.240 [INFO] 91.8 %. Size, fluence cut = 1780 3.2e-07
# 14:10:16.542 [INFO] Subsampling done in 6.235 s
# 14:10:29.850 [INFO] KS calculations done in 13.308 s
# 14:10:37.522 [INFO] CDF calculation done in 7.671 s
# 14:10:37.557 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 14:10:37.558 [INFO] 93.9 %. Size, fluence cut = 1780 1.8e-07
# 14:10:45.802 [INFO] Subsampling done in 8.169 s
# 14:11:04.349 [INFO] KS calculations done in 18.546 s
# 14:11:15.044 [INFO] CDF calculation done in 10.694 s
# 14:11:15.096 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 14:11:15.096 [INFO] 95.9 %. Size, fluence cut = 1780 1e-07
# 14:11:25.686 [INFO] Subsampling done in 10.506 s
# 14:11:52.811 [INFO] KS calculations done in 27.124 s
# 14:12:07.814 [INFO] CDF calculation done in 15.002 s
# 14:12:07.896 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 14:12:07.897 [INFO] 98.0 %. Size, fluence cut = 1780 5.7e-08
# 14:12:27.405 [INFO] Subsampling done in 19.416 s
# 14:13:04.955 [INFO] KS calculations done in 37.549 s
# 14:13:25.144 [INFO] CDF calculation done in 20.188 s
# 14:13:25.257 [INFO] Fraction of samples different at the 95% confidence level : 1.0

# %%
# WARNING: long computing time (at least 10 min)
# Same thing with Amati-like scenarios subsampling from k=0 instead of k=2
if not load_files:
    frac = np.zeros((len(size), len(flnc_cuts)))
    k=0
    for i, j in product(range(len(size)), range(len(flnc_cuts))):
        log.info("{:.1f} %. Size, fluence cut = {} {}".format(100*k/(len(size)*len(flnc_cuts)), size[i], flnc_cuts[j]))
        frac[i,j]= st.subsample_and_KS(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                                     dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])],
                                     key='z',
                                     precision=precision,
                                     bins=np.linspace(0,20,precision+1),
                                     N_sub=size[i],
                                     N_bs=1000,
                                     subsample2=False)
        log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
        k+=1
    p_discr_z['A'] = frac
# Out:
# 14:13:25.265 [INFO] 0.0 %. Size, fluence cut = 56 1.8e-06
# 14:13:26.051 [INFO] Subsampling done in 0.753 s
# 14:13:37.392 [INFO] KS calculations done in 11.340 s
# 14:13:44.358 [INFO] CDF calculation done in 6.965 s
# 14:13:44.386 [INFO] Fraction of samples different at the 95% confidence level : 0.048
# 14:13:44.387 [INFO] 2.0 %. Size, fluence cut = 56 1e-06
# 14:13:45.543 [INFO] Subsampling done in 1.115 s
# 14:14:05.660 [INFO] KS calculations done in 20.116 s
# 14:14:17.924 [INFO] CDF calculation done in 12.264 s
# 14:14:17.979 [INFO] Fraction of samples different at the 95% confidence level : 0.058
# 14:14:17.980 [INFO] 4.1 %. Size, fluence cut = 56 5.6e-07
# 14:14:19.757 [INFO] Subsampling done in 1.725 s
# 14:14:51.103 [INFO] KS calculations done in 31.346 s
# 14:15:09.855 [INFO] CDF calculation done in 18.751 s
# 14:15:09.977 [INFO] Fraction of samples different at the 95% confidence level : 0.108
# 14:15:09.978 [INFO] 6.1 %. Size, fluence cut = 56 3.2e-07
# 14:15:13.111 [INFO] Subsampling done in 3.036 s
# 14:15:59.386 [INFO] KS calculations done in 46.274 s
# 14:16:26.911 [INFO] CDF calculation done in 27.524 s
# 14:16:27.054 [INFO] Fraction of samples different at the 95% confidence level : 0.131
# 14:16:27.054 [INFO] 8.2 %. Size, fluence cut = 56 1.8e-07
# 14:16:30.720 [INFO] Subsampling done in 3.584 s
# 14:17:36.282 [INFO] KS calculations done in 65.561 s
# 14:18:14.900 [INFO] CDF calculation done in 38.618 s
# 14:18:15.101 [INFO] Fraction of samples different at the 95% confidence level : 0.153
# 14:18:15.101 [INFO] 10.2 %. Size, fluence cut = 56 1e-07
# 14:18:20.590 [INFO] Subsampling done in 5.398 s
# 14:19:48.084 [INFO] KS calculations done in 87.493 s
# 14:20:40.872 [INFO] CDF calculation done in 52.788 s
# 14:20:41.191 [INFO] Fraction of samples different at the 95% confidence level : 0.175
# 14:20:41.192 [INFO] 12.2 %. Size, fluence cut = 56 5.7e-08
# 14:20:49.344 [INFO] Subsampling done in 8.035 s
# 14:22:37.520 [INFO] KS calculations done in 108.175 s
# 14:23:40.600 [INFO] CDF calculation done in 63.079 s
# 14:23:41.019 [INFO] Fraction of samples different at the 95% confidence level : 0.176
# 14:23:41.019 [INFO] 14.3 %. Size, fluence cut = 100 1.8e-06
# 14:23:41.800 [INFO] Subsampling done in 0.743 s
# 14:23:54.138 [INFO] KS calculations done in 12.338 s
# 14:24:01.619 [INFO] CDF calculation done in 7.480 s
# 14:24:01.648 [INFO] Fraction of samples different at the 95% confidence level : 0.049
# 14:24:01.648 [INFO] 16.3 %. Size, fluence cut = 100 1e-06
# 14:24:02.821 [INFO] Subsampling done in 1.131 s
# 14:24:22.242 [INFO] KS calculations done in 19.421 s
# 14:24:34.576 [INFO] CDF calculation done in 12.334 s
# 14:24:34.624 [INFO] Fraction of samples different at the 95% confidence level : 0.086
# 14:24:34.625 [INFO] 18.4 %. Size, fluence cut = 100 5.6e-07
# 14:24:36.511 [INFO] Subsampling done in 1.833 s
# 14:25:09.108 [INFO] KS calculations done in 32.595 s
# 14:25:28.211 [INFO] CDF calculation done in 19.103 s
# 14:25:28.295 [INFO] Fraction of samples different at the 95% confidence level : 0.159
# 14:25:28.296 [INFO] 20.4 %. Size, fluence cut = 100 3.2e-07
# 14:25:31.114 [INFO] Subsampling done in 2.738 s
# 14:26:18.139 [INFO] KS calculations done in 47.024 s
# 14:26:45.788 [INFO] CDF calculation done in 27.648 s
# 14:26:45.933 [INFO] Fraction of samples different at the 95% confidence level : 0.178
# 14:26:45.934 [INFO] 22.4 %. Size, fluence cut = 100 1.8e-07
# 14:26:49.751 [INFO] Subsampling done in 3.724 s
# 14:27:55.693 [INFO] KS calculations done in 65.941 s
# 14:28:33.646 [INFO] CDF calculation done in 37.952 s
# 14:28:33.830 [INFO] Fraction of samples different at the 95% confidence level : 0.256
# 14:28:33.831 [INFO] 24.5 %. Size, fluence cut = 100 1e-07
# 14:28:38.931 [INFO] Subsampling done in 5.015 s
# 14:30:06.606 [INFO] KS calculations done in 87.675 s
# 14:30:58.116 [INFO] CDF calculation done in 51.508 s
# 14:30:58.383 [INFO] Fraction of samples different at the 95% confidence level : 0.248
# 14:30:58.384 [INFO] 26.5 %. Size, fluence cut = 100 5.7e-08
# 14:31:06.552 [INFO] Subsampling done in 8.074 s
# 14:32:55.944 [INFO] KS calculations done in 109.392 s
# 14:33:59.007 [INFO] CDF calculation done in 63.062 s
# 14:33:59.361 [INFO] Fraction of samples different at the 95% confidence level : 0.249
# 14:33:59.362 [INFO] 28.6 %. Size, fluence cut = 178 1.8e-06
# 14:34:00.183 [INFO] Subsampling done in 0.786 s
# 14:34:13.791 [INFO] KS calculations done in 13.607 s
# 14:34:21.638 [INFO] CDF calculation done in 7.846 s
# 14:34:21.683 [INFO] Fraction of samples different at the 95% confidence level : 0.041
# 14:34:21.684 [INFO] 30.6 %. Size, fluence cut = 178 1e-06
# 14:34:23.059 [INFO] Subsampling done in 1.326 s
# 14:34:44.173 [INFO] KS calculations done in 21.113 s
# 14:34:56.834 [INFO] CDF calculation done in 12.661 s
# 14:34:56.883 [INFO] Fraction of samples different at the 95% confidence level : 0.122
# 14:34:56.884 [INFO] 32.7 %. Size, fluence cut = 178 5.6e-07
# 14:34:58.673 [INFO] Subsampling done in 1.738 s
# 14:35:32.273 [INFO] KS calculations done in 33.599 s
# 14:35:51.156 [INFO] CDF calculation done in 18.883 s
# 14:35:51.239 [INFO] Fraction of samples different at the 95% confidence level : 0.244
# 14:35:51.240 [INFO] 34.7 %. Size, fluence cut = 178 3.2e-07
# 14:35:53.863 [INFO] Subsampling done in 2.558 s
# 14:36:40.984 [INFO] KS calculations done in 47.121 s
# 14:37:08.908 [INFO] CDF calculation done in 27.923 s
# 14:37:09.033 [INFO] Fraction of samples different at the 95% confidence level : 0.318
# 14:37:09.034 [INFO] 36.7 %. Size, fluence cut = 178 1.8e-07
# 14:37:12.779 [INFO] Subsampling done in 3.663 s
# 14:38:19.003 [INFO] KS calculations done in 66.223 s
# 14:38:56.991 [INFO] CDF calculation done in 37.987 s
# 14:38:57.189 [INFO] Fraction of samples different at the 95% confidence level : 0.399
# 14:38:57.190 [INFO] 38.8 %. Size, fluence cut = 178 1e-07
# 14:39:02.204 [INFO] Subsampling done in 4.924 s
# 14:40:24.465 [INFO] KS calculations done in 82.260 s
# 14:41:13.041 [INFO] CDF calculation done in 48.576 s
# 14:41:13.294 [INFO] Fraction of samples different at the 95% confidence level : 0.435
# 14:41:13.295 [INFO] 40.8 %. Size, fluence cut = 178 5.7e-08
# 14:41:19.668 [INFO] Subsampling done in 6.278 s
# 14:43:05.669 [INFO] KS calculations done in 106.000 s
# 14:44:05.536 [INFO] CDF calculation done in 59.867 s
# 14:44:05.855 [INFO] Fraction of samples different at the 95% confidence level : 0.474
# 14:44:05.856 [INFO] 42.9 %. Size, fluence cut = 316 1.8e-06
# 14:44:06.618 [INFO] Subsampling done in 0.730 s
# 14:44:17.568 [INFO] KS calculations done in 10.949 s
# 14:44:24.446 [INFO] CDF calculation done in 6.877 s
# 14:44:24.473 [INFO] Fraction of samples different at the 95% confidence level : 0.058
# 14:44:24.474 [INFO] 44.9 %. Size, fluence cut = 316 1e-06
# 14:44:25.593 [INFO] Subsampling done in 1.079 s
# 14:44:44.335 [INFO] KS calculations done in 18.741 s
# 14:44:55.862 [INFO] CDF calculation done in 11.526 s
# 14:44:55.908 [INFO] Fraction of samples different at the 95% confidence level : 0.187
# 14:44:55.909 [INFO] 46.9 %. Size, fluence cut = 316 5.6e-07
# 14:44:57.651 [INFO] Subsampling done in 1.693 s
# 14:45:27.009 [INFO] KS calculations done in 29.357 s
# 14:45:45.569 [INFO] CDF calculation done in 18.559 s
# 14:45:45.642 [INFO] Fraction of samples different at the 95% confidence level : 0.392
# 14:45:45.643 [INFO] 49.0 %. Size, fluence cut = 316 3.2e-07
# 14:45:48.166 [INFO] Subsampling done in 2.460 s
# 14:46:34.640 [INFO] KS calculations done in 46.473 s
# 14:47:01.727 [INFO] CDF calculation done in 27.087 s
# 14:47:01.842 [INFO] Fraction of samples different at the 95% confidence level : 0.56
# 14:47:01.843 [INFO] 51.0 %. Size, fluence cut = 316 1.8e-07
# 14:47:05.370 [INFO] Subsampling done in 3.454 s
# 14:48:10.742 [INFO] KS calculations done in 65.371 s
# 14:48:48.633 [INFO] CDF calculation done in 37.890 s
# 14:48:48.808 [INFO] Fraction of samples different at the 95% confidence level : 0.657
# 14:48:48.809 [INFO] 53.1 %. Size, fluence cut = 316 1e-07
# 14:48:53.771 [INFO] Subsampling done in 4.879 s
# 14:50:21.230 [INFO] KS calculations done in 87.459 s
# 14:51:12.316 [INFO] CDF calculation done in 51.085 s
# 14:51:12.642 [INFO] Fraction of samples different at the 95% confidence level : 0.684
# 14:51:12.643 [INFO] 55.1 %. Size, fluence cut = 316 5.7e-08
# 14:51:20.499 [INFO] Subsampling done in 7.732 s
# 14:53:07.863 [INFO] KS calculations done in 107.363 s
# 14:54:10.879 [INFO] CDF calculation done in 63.015 s
# 14:54:11.195 [INFO] Fraction of samples different at the 95% confidence level : 0.713
# 14:54:11.196 [INFO] 57.1 %. Size, fluence cut = 562 1.8e-06
# 14:54:11.975 [INFO] Subsampling done in 0.747 s
# 14:54:24.311 [INFO] KS calculations done in 12.336 s
# 14:54:31.511 [INFO] CDF calculation done in 7.199 s
# 14:54:31.543 [INFO] Fraction of samples different at the 95% confidence level : 0.064
# 14:54:31.544 [INFO] 59.2 %. Size, fluence cut = 562 1e-06
# 14:54:32.714 [INFO] Subsampling done in 1.128 s
# 14:54:54.971 [INFO] KS calculations done in 22.256 s
# 14:55:07.716 [INFO] CDF calculation done in 12.744 s
# 14:55:07.767 [INFO] Fraction of samples different at the 95% confidence level : 0.292
# 14:55:07.768 [INFO] 61.2 %. Size, fluence cut = 562 5.6e-07
# 14:55:09.763 [INFO] Subsampling done in 1.943 s
# 14:55:43.057 [INFO] KS calculations done in 33.294 s
# 14:56:02.078 [INFO] CDF calculation done in 19.021 s
# 14:56:02.162 [INFO] Fraction of samples different at the 95% confidence level : 0.626
# 14:56:02.163 [INFO] 63.3 %. Size, fluence cut = 562 3.2e-07
# 14:56:04.868 [INFO] Subsampling done in 2.639 s
# 14:56:54.577 [INFO] KS calculations done in 49.709 s
# 14:57:21.806 [INFO] CDF calculation done in 27.228 s
# 14:57:21.929 [INFO] Fraction of samples different at the 95% confidence level : 0.813
# 14:57:21.930 [INFO] 65.3 %. Size, fluence cut = 562 1.8e-07
# 14:57:25.650 [INFO] Subsampling done in 3.648 s
# 14:58:34.208 [INFO] KS calculations done in 68.558 s
# 14:59:12.938 [INFO] CDF calculation done in 38.729 s
# 14:59:13.137 [INFO] Fraction of samples different at the 95% confidence level : 0.915
# 14:59:13.138 [INFO] 67.3 %. Size, fluence cut = 562 1e-07
# 14:59:18.488 [INFO] Subsampling done in 5.261 s
# 15:00:49.779 [INFO] KS calculations done in 91.290 s
# 15:01:41.179 [INFO] CDF calculation done in 51.399 s
# 15:01:41.462 [INFO] Fraction of samples different at the 95% confidence level : 0.916
# 15:01:41.462 [INFO] 69.4 %. Size, fluence cut = 562 5.7e-08
# 15:01:48.369 [INFO] Subsampling done in 6.806 s
# 15:03:39.642 [INFO] KS calculations done in 111.273 s
# 15:04:43.443 [INFO] CDF calculation done in 63.800 s
# 15:04:43.771 [INFO] Fraction of samples different at the 95% confidence level : 0.932
# 15:04:43.771 [INFO] 71.4 %. Size, fluence cut = 1000 1.8e-06
# 15:04:44.553 [INFO] Subsampling done in 0.749 s
# 15:04:57.666 [INFO] KS calculations done in 13.112 s
# 15:05:05.083 [INFO] CDF calculation done in 7.417 s
# 15:05:05.116 [INFO] Fraction of samples different at the 95% confidence level : 0.089
# 15:05:05.117 [INFO] 73.5 %. Size, fluence cut = 1000 1e-06
# 15:05:06.377 [INFO] Subsampling done in 1.217 s
# 15:05:28.181 [INFO] KS calculations done in 21.803 s
# 15:05:40.275 [INFO] CDF calculation done in 12.093 s
# 15:05:40.328 [INFO] Fraction of samples different at the 95% confidence level : 0.506
# 15:05:40.329 [INFO] 75.5 %. Size, fluence cut = 1000 5.6e-07
# 15:05:42.160 [INFO] Subsampling done in 1.777 s
# 15:06:15.909 [INFO] KS calculations done in 33.749 s
# 15:06:34.736 [INFO] CDF calculation done in 18.826 s
# 15:06:34.817 [INFO] Fraction of samples different at the 95% confidence level : 0.867
# 15:06:34.817 [INFO] 77.6 %. Size, fluence cut = 1000 3.2e-07
# 15:06:37.496 [INFO] Subsampling done in 2.612 s
# 15:07:27.630 [INFO] KS calculations done in 50.133 s
# 15:07:55.160 [INFO] CDF calculation done in 27.530 s
# 15:07:55.304 [INFO] Fraction of samples different at the 95% confidence level : 0.971
# 15:07:55.305 [INFO] 79.6 %. Size, fluence cut = 1000 1.8e-07
# 15:07:59.828 [INFO] Subsampling done in 4.425 s
# 15:09:09.962 [INFO] KS calculations done in 70.133 s
# 15:09:48.830 [INFO] CDF calculation done in 38.867 s
# 15:09:49.011 [INFO] Fraction of samples different at the 95% confidence level : 0.996
# 15:09:49.011 [INFO] 81.6 %. Size, fluence cut = 1000 1e-07
# 15:09:53.897 [INFO] Subsampling done in 4.798 s
# 15:11:21.940 [INFO] KS calculations done in 88.043 s
# 15:12:15.298 [INFO] CDF calculation done in 53.357 s
# 15:12:15.561 [INFO] Fraction of samples different at the 95% confidence level : 0.997
# 15:12:15.562 [INFO] 83.7 %. Size, fluence cut = 1000 5.7e-08
# 15:12:23.594 [INFO] Subsampling done in 7.926 s
# 15:14:16.381 [INFO] KS calculations done in 112.786 s
# 15:15:20.015 [INFO] CDF calculation done in 63.633 s
# 15:15:20.334 [INFO] Fraction of samples different at the 95% confidence level : 0.998
# 15:15:20.335 [INFO] 85.7 %. Size, fluence cut = 1780 1.8e-06
# 15:15:21.239 [INFO] Subsampling done in 0.872 s
# 15:15:35.208 [INFO] KS calculations done in 13.968 s
# 15:15:42.378 [INFO] CDF calculation done in 7.169 s
# 15:15:42.411 [INFO] Fraction of samples different at the 95% confidence level : 0.108
# 15:15:42.412 [INFO] 87.8 %. Size, fluence cut = 1780 1e-06
# 15:15:43.579 [INFO] Subsampling done in 1.125 s
# 15:16:05.480 [INFO] KS calculations done in 21.901 s
# 15:16:18.046 [INFO] CDF calculation done in 12.565 s
# 15:16:18.099 [INFO] Fraction of samples different at the 95% confidence level : 0.751
# 15:16:18.100 [INFO] 89.8 %. Size, fluence cut = 1780 5.6e-07
# 15:16:20.191 [INFO] Subsampling done in 2.028 s
# 15:16:54.856 [INFO] KS calculations done in 34.665 s
# 15:17:13.786 [INFO] CDF calculation done in 18.930 s
# 15:17:13.866 [INFO] Fraction of samples different at the 95% confidence level : 0.989
# 15:17:13.867 [INFO] 91.8 %. Size, fluence cut = 1780 3.2e-07
# 15:17:16.677 [INFO] Subsampling done in 2.745 s
# 15:18:06.663 [INFO] KS calculations done in 49.985 s
# 15:18:34.194 [INFO] CDF calculation done in 27.530 s
# 15:18:34.311 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 15:18:34.311 [INFO] 93.9 %. Size, fluence cut = 1780 1.8e-07
# 15:18:38.112 [INFO] Subsampling done in 3.726 s
# 15:19:47.925 [INFO] KS calculations done in 69.812 s
# 15:20:26.451 [INFO] CDF calculation done in 38.526 s
# 15:20:26.631 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 15:20:26.632 [INFO] 95.9 %. Size, fluence cut = 1780 1e-07
# 15:20:31.974 [INFO] Subsampling done in 5.251 s
# 15:22:05.036 [INFO] KS calculations done in 93.062 s
# 15:22:56.916 [INFO] CDF calculation done in 51.879 s
# 15:22:57.180 [INFO] Fraction of samples different at the 95% confidence level : 1.0
# 15:22:57.181 [INFO] 98.0 %. Size, fluence cut = 1780 5.7e-08
# 15:23:04.133 [INFO] Subsampling done in 6.849 s
# 15:24:57.709 [INFO] KS calculations done in 113.575 s
# 15:26:01.165 [INFO] CDF calculation done in 63.455 s
# 15:26:01.492 [INFO] Fraction of samples different at the 95% confidence level : 1.0

# %%
def plot_fluence_cut_vs_sample_size(size, flnc_cuts, frac, show_indiv_pts=False):
    fig, ax = plt.subplots(figsize=(10,8))
    log_size_2D, log_flnc_cuts_2D = np.meshgrid(np.log10(size), np.log10(flnc_cuts))
    N_colors = 10
    # WARNGING : must use the transpose of frac here because of the way contourf expects the input
    art = ax.contourf(log_size_2D, log_flnc_cuts_2D, frac.T, levels=9)
    cb = fig.colorbar(art)
    if show_indiv_pts:
        for i, j in product(range(len(size)), range(len(flnc_cuts))):
            ax.scatter(np.log10(size[i]), np.log10(flnc_cuts[j]), s=10, marker='.', color='k')
            ax.text(np.log10(size[i]), np.log10(flnc_cuts[j]), "{:.2f}".format(frac[i,j]))
    cb.set_label(r"$p^{2\sigma}_{\rm discr}$")
    ax.set_xlabel("log sample size")
    ax.set_ylabel("log Fluence cut [erg/cm$^2$]")
    return

# %%
# Create the 2D plane 'fluence cut' vs 'sample size' and plot the probability of discriminating between
# k=0 and k=2 models at the 2 sigma confidence level for the LogNormal scenarios
for key, value in p_discr_z.items():
    print(key)
    plot_fluence_cut_vs_sample_size(size, flnc_cuts, value)
    ax = plt.gca()
    ax.scatter(np.log10(117), -6, s=200, marker='*', edgecolor='w', color='k', label='SHOALS')
    ax.legend(loc='best')
    plt.savefig(f'/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/flnc_sampsize_{key}.pdf')
    plt.show()
# Out:
# LN
# LN2
# A2
# A

# %%
# Turn the data into DataFrames and save them
if not load_files:
    for mod, frac in p_discr_z.items():
        df_temp = pd.DataFrame(data=frac, index=size.astype(str), columns=flnc_cuts.astype(str))
        df_temp.to_parquet(paths_to_dir['output']+ f'/p_discr_z_{mod}')

# %%
# Same thing but with the eBAT6 sample
pflx_cuts = np.logspace(np.log10(0.05), np.log10(3), 5)
size = np.array([56, 100, 178, 316, 562, 1000, 1780])
p_discr_z_BAT6 = {}
load_files=False
if load_files:
    for mod in ['LN','A']:
        try:
            p_discr_z_BAT6[mod] = pd.read_parquet(paths_to_dir['output']+ f'/p_discr_z_BAT6{mod}').to_numpy()
        except Exception:
            pass

# %%
import time
from stats import *

def subsample_and_KS(df1, df2, N_sub, key, confidence=95.0, N_bs=100, precision=500, bins=None, create_CDF=True,
    show_plot=False, label1=None, label2=None, subsample1=True, subsample2=True, color1=None, color2=None):
    """
        Compute the K-S test between a subsample of size N_sub.
        Repeat the K-S test for N_bs bootstraps and create a distribution of p-values.
    """
    t1 = time.time()
    if subsample1:
        subsamp1 = subsample_with_bootstrap(df1, key=key, N_sub=N_sub, N_bs=N_bs)
    else:
        subsamp1 = df1[key].to_numpy()[:,np.newaxis] * np.ones(N_bs)
        subsamp1 = subsamp1.T
    if subsample2:
        subsamp2 = subsample_with_bootstrap(df2, key=key, N_sub=N_sub, N_bs=N_bs)
    else:
        subsamp2 = df2[key].to_numpy()[:,np.newaxis] * np.ones(N_bs)
        subsamp2 = subsamp2.T
    t2 = time.time()
    log.info(f"Subsampling done in {t2-t1:.3f} s")

    t1 = time.time()
    D_stat, p_value = compute_KS_with_bootstrap(subsamp1, subsamp2, N_bs)
    t2 = time.time()
    log.info(f"KS calculations done in {t2-t1:.3f} s")

    if create_CDF:
        t1 = time.time()
        CDF1 = CDF_with_bootstrap(subsamp1, bins=bins)
        CDF2 = CDF_with_bootstrap(subsamp2, bins=bins)
        med1, lw1, up1 = compute_CDF_quantiles(CDF1, confidence=confidence)
        med2, lw2, up2 = compute_CDF_quantiles(CDF2, confidence=confidence)
        t2 = time.time()
        log.info(f"CDF calculation done in {t2-t1:.3f} s")

    pfrac = len(p_value[np.where(p_value < (1.-confidence/100.))[0]])/len(p_value)

    if show_plot:
        pf.plot_CDFs_and_KS_results(bins=bins, med1=med1, med2=med2, lw1=lw1, lw2=lw2, up1=up1, up2=up2,
                                    D_stat=D_stat,
                                    p_value=p_value,
                                    confidence=confidence,
                                    pfrac=pfrac,
                                    label1=label1,
                                    label2=label2,
                                    color1=color1,
                                    color2=color2)

    return pfrac

# %%
subsample_and_KS(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['pht_pflx_BAT']>=0.14)],
                             dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['pht_pflx_BAT']>=0.14)],
                             key='z', create_CDF=True, show_plot=True,
                             precision=precision,
                             bins=np.linspace(0,20,precision+1),
                             N_sub=178,
                             N_bs=5000,
                             subsample1=False)
plt.gcf().axes[0].set_xlim(0,10)
# Out:
# 10:55:40.210 [INFO] Subsampling done in 63.544 s
# 10:57:53.369 [INFO] KS calculations done in 133.159 s
# 10:59:10.945 [INFO] CDF calculation done in 77.575 s
# 10:59:10.994 [WARNING] No handles with labels found to put in legend.
# 10:59:11.001 [WARNING] No handles with labels found to put in legend.
# (0, 10)

# %%
subsample_and_KS(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['pht_pflx_BAT']>=0.387)],
                             dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['pht_pflx_BAT']>=0.387)],
                             key='z', create_CDF=True, show_plot=True,
                             precision=precision,
                             bins=np.linspace(0,20,precision+1),
                             N_sub=178,
                             N_bs=5000,
                             subsample1=False)
plt.gcf().axes[0].set_xlim(0,10)
# Out:
# 10:50:28.651 [INFO] Subsampling done in 29.729 s
# 10:51:34.859 [INFO] KS calculations done in 66.207 s
# 10:52:14.465 [INFO] CDF calculation done in 39.605 s
# 10:52:14.512 [WARNING] No handles with labels found to put in legend.
# 10:52:14.630 [WARNING] No handles with labels found to put in legend.
# (0, 10)

# %%
precision=500
if not load_files:
    for mod in ['A']:
        frac = np.zeros((len(size), len(pflx_cuts)))
        k=0
        for i, j in product(range(len(size)), range(len(pflx_cuts))):
            log.info("{:.1f}% Size, pflx cut = {} {}".format(100*k/(len(size)*len(pflx_cuts)), size[i], pflx_cuts[j]))
            frac[i,j]= st.subsample_and_KS(dfs[f'k0_{mod}_nF'].properties[(dfs[f'k0_{mod}_nF'].properties['pht_pflx_BAT']>=pflx_cuts[j])],
                             dfs[f'k2_{mod}_nF'].properties[(dfs[f'k2_{mod}_nF'].properties['pht_pflx_BAT']>=pflx_cuts[j])],
                             key='z',
                             precision=precision,
                             bins=np.linspace(0,20,precision+1),
                             N_sub=size[i],
                             N_bs=1000,
                             subsample1=False)
            log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
            k+=1
        p_discr_z_BAT6[mod] = frac
# Out:
# 10:25:09.316 [INFO] 0.0% Size, pflx cut = 56 0.049999999999999996
# 10:25:31.125 [INFO] Subsampling done in 21.542 s
# 10:26:15.677 [INFO] KS calculations done in 44.551 s
# 10:26:42.290 [INFO] CDF calculation done in 26.612 s
# 10:26:42.443 [INFO] Fraction of samples different at the 95% confidence level : 0.047
# 10:26:42.444 [INFO] 2.9% Size, pflx cut = 56 0.13915788418568703
# 10:26:53.892 [INFO] Subsampling done in 11.343 s
# 10:27:18.511 [INFO] KS calculations done in 24.618 s
# 10:27:33.326 [INFO] CDF calculation done in 14.815 s
# 10:27:33.409 [INFO] Fraction of samples different at the 95% confidence level : 0.068
# 10:27:33.410 [INFO] 5.7% Size, pflx cut = 56 0.38729833462074165
# 10:27:40.002 [INFO] Subsampling done in 6.514 s
# 10:27:51.706 [INFO] KS calculations done in 11.704 s
# 10:27:58.941 [INFO] CDF calculation done in 7.234 s
# 10:27:58.982 [INFO] Fraction of samples different at the 95% confidence level : 0.11
# 10:27:58.983 [INFO] 8.6% Size, pflx cut = 56 1.0779123358892524
# 10:28:01.605 [INFO] Subsampling done in 2.573 s
# 10:28:05.949 [INFO] KS calculations done in 4.342 s
# 10:28:08.581 [INFO] CDF calculation done in 2.632 s
# 10:28:08.600 [INFO] Fraction of samples different at the 95% confidence level : 0.048
# 10:28:08.601 [INFO] 11.4% Size, pflx cut = 56 3.0
# 10:28:09.665 [INFO] Subsampling done in 1.037 s
# 10:28:11.481 [INFO] KS calculations done in 1.815 s
# 10:28:12.787 [INFO] CDF calculation done in 1.305 s
# 10:28:12.795 [INFO] Fraction of samples different at the 95% confidence level : 0.042
# 10:28:12.796 [INFO] 14.3% Size, pflx cut = 100 0.049999999999999996
# 10:28:32.445 [INFO] Subsampling done in 19.546 s
# 10:29:18.178 [INFO] KS calculations done in 45.733 s
# 10:29:44.773 [INFO] CDF calculation done in 26.593 s
# 10:29:44.927 [INFO] Fraction of samples different at the 95% confidence level : 0.064
# 10:29:44.927 [INFO] 17.1% Size, pflx cut = 100 0.13915788418568703
# 10:29:57.622 [INFO] Subsampling done in 12.609 s
# 10:30:22.195 [INFO] KS calculations done in 24.573 s
# 10:30:36.832 [INFO] CDF calculation done in 14.636 s
# 10:30:36.979 [INFO] Fraction of samples different at the 95% confidence level : 0.129
# 10:30:36.981 [INFO] 20.0% Size, pflx cut = 100 0.38729833462074165
# 10:30:43.687 [INFO] Subsampling done in 6.563 s
# 10:30:55.571 [INFO] KS calculations done in 11.883 s
# 10:31:03.195 [INFO] CDF calculation done in 7.623 s
# 10:31:03.251 [INFO] Fraction of samples different at the 95% confidence level : 0.146
# 10:31:03.252 [INFO] 22.9% Size, pflx cut = 100 1.0779123358892524
# 10:31:05.873 [INFO] Subsampling done in 2.566 s
# 10:31:10.414 [INFO] KS calculations done in 4.541 s
# 10:31:13.614 [INFO] CDF calculation done in 3.199 s
# 10:31:13.631 [INFO] Fraction of samples different at the 95% confidence level : 0.057
# 10:31:13.632 [INFO] 25.7% Size, pflx cut = 100 3.0
# 10:31:14.731 [INFO] Subsampling done in 1.069 s
# 10:31:16.630 [INFO] KS calculations done in 1.899 s
# 10:31:17.830 [INFO] CDF calculation done in 1.199 s
# 10:31:17.841 [INFO] Fraction of samples different at the 95% confidence level : 0.057
# 10:31:17.841 [INFO] 28.6% Size, pflx cut = 178 0.049999999999999996
# 10:31:38.218 [INFO] Subsampling done in 20.259 s
# 10:32:24.220 [INFO] KS calculations done in 46.001 s
# 10:32:50.267 [INFO] CDF calculation done in 26.046 s
# 10:32:50.448 [INFO] Fraction of samples different at the 95% confidence level : 0.096
# 10:32:50.448 [INFO] 31.4% Size, pflx cut = 178 0.13915788418568703
# 10:33:01.701 [INFO] Subsampling done in 11.151 s
# 10:33:26.657 [INFO] KS calculations done in 24.956 s
# 10:33:41.236 [INFO] CDF calculation done in 14.578 s
# 10:33:41.332 [INFO] Fraction of samples different at the 95% confidence level : 0.209
# 10:33:41.333 [INFO] 34.3% Size, pflx cut = 178 0.38729833462074165
# 10:33:47.905 [INFO] Subsampling done in 6.484 s
# 10:34:00.392 [INFO] KS calculations done in 12.486 s
# 10:34:08.335 [INFO] CDF calculation done in 7.942 s
# 10:34:08.395 [INFO] Fraction of samples different at the 95% confidence level : 0.237
# 10:34:08.396 [INFO] 37.1% Size, pflx cut = 178 1.0779123358892524
# 10:34:11.627 [INFO] Subsampling done in 3.132 s
# 10:34:17.175 [INFO] KS calculations done in 5.548 s
# 10:34:20.474 [INFO] CDF calculation done in 3.298 s
# 10:34:20.495 [INFO] Fraction of samples different at the 95% confidence level : 0.075
# 10:34:20.496 [INFO] 40.0% Size, pflx cut = 178 3.0
# 10:34:21.723 [INFO] Subsampling done in 1.185 s
# 10:34:23.812 [INFO] KS calculations done in 2.088 s
# 10:34:25.118 [INFO] CDF calculation done in 1.306 s
# 10:34:25.127 [INFO] Fraction of samples different at the 95% confidence level : 0.067
# 10:34:25.128 [INFO] 42.9% Size, pflx cut = 316 0.049999999999999996
# 10:34:48.372 [INFO] Subsampling done in 23.100 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-670b48349a5c> in <module>
#      13                              N_sub=size[i],
#      14                              N_bs=1000,
# ---> 15                              subsample1=False)
#      16             log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
#      17             k+=1
#
# ~/Science_projects/GRB_population_model/src/stats.py in subsample_and_KS(df1, df2, N_sub, key, confidence, N_bs, precision, bins, show_plot, label1, label2, subsample1, subsample2, color1, color2)
#     100
#     101     t1 = time.time()
# --> 102     D_stat, p_value = compute_KS_with_bootstrap(subsamp1, subsamp2, N_bs)
#     103     t2 = time.time()
#     104     log.info(f"KS calculations done in {t2-t1:.3f} s")
#
# ~/Science_projects/GRB_population_model/src/stats.py in compute_KS_with_bootstrap(samples1, samples2, N_bs)
#     192     D_stat = np.zeros(N_bs)
#     193     p_value = np.zeros(N_bs)
# --> 194     for i in range(N_bs):
#     195         D_stat[i], p_value[i] = ks_2samp(samples1[i], samples2[i])
#     196     return D_stat, p_value
#
# ~/miniconda3/envs/python3/lib/python3.7/site-packages/scipy/stats/stats.py in ks_2samp(data1, data2, alternative, mode)
#    6182     """
#    6183     LARGE_N = 10000  # 'auto' will attempt to be exact if n1,n2 <= LARGE_N
# -> 6184     data1 = np.sort(data1)
#    6185     data2 = np.sort(data2)
#    6186     n1 = data1.shape[0]
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# ~/miniconda3/envs/python3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     987     else:
#     988         a = asanyarray(a).copy(order="K")
# --> 989     a.sort(axis=axis, kind=kind, order=order)
#     990     return a
#     991
#
# KeyboardInterrupt:

# %%
for mod, frac in p_discr_z_BAT6.items():
        df_temp = pd.DataFrame(data=frac, index=size.astype(str), columns=pflx_cuts.astype(str))
        df_temp.to_parquet(f'/Users/palmerio/Science_projects/GRB_population_model/model_outputs_non-dockerized/best_populations/p_discr_z_BAT6_{mod}')

# %%
def plot_pflx_cut_vs_sample_size(size, pflx_cuts, frac, show_indiv_pts=False):
    fig, ax = plt.subplots(figsize=(10,8))
    log_size_2D, log_pflx_cuts_2D = np.meshgrid(np.log10(size), np.log10(pflx_cuts))
    N_colors = 10
    # WARNGING : must use the transpose of frac here because of the way contourf expects the input
    art = ax.contourf(log_size_2D, log_pflx_cuts_2D, frac.T, levels=9)
    cb = fig.colorbar(art)
    if show_indiv_pts:
        for i, j in product(range(len(size)), range(len(pflx_cuts))):
            ax.scatter(np.log10(size[i]), np.log10(pflx_cuts[j]), s=10, marker='.', color='k')
            ax.text(np.log10(size[i]), np.log10(pflx_cuts[j]), "{:.2f}".format(frac[i,j]))
    cb.set_label(r"$p^{2\sigma}_{\rm discr}$")
    ax.set_xlabel("log sample size")
    ax.set_ylabel("log Peak flux cut [ph/s/cm$^2$]")
    return

# Create the 2D plane 'pflx cut' vs 'sample size' and plot the probability of discriminating between
# k=0 and k=2 models at the 2 sigma confidence level for the LogNormal scenarios
for key, value in p_discr_z_BAT6.items():
    print(key)
    plot_pflx_cut_vs_sample_size(size, pflx_cuts, value, show_indiv_pts=True)
    ax = plt.gca()
    ax.scatter(np.log10(99), np.log10(2.6), s=200, marker='*', edgecolor='w', color='k', label='eBAT6')
    ax.axhline(np.log10(0.068), ls='--', color='k', label='BATSE limit from Stern+01')
    ax.legend(loc='best')
    plt.savefig(f'/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/pflx_sampsize_{key}.pdf')
    plt.show()
# Out:
# LN
# A

# %%
# Now we want to look at the Ep-Eiso plane and the Eiso distribution to compare with Atteia+17.
fig, ax = plt.subplots(figsize=(10,8))
from matplotlib.transforms import blended_transform_factory
tform = blended_transform_factory(ax.transData, ax.transAxes)
    
ax.fill_between([54,54.4], [0.3,0.3], transform=tform, color='lightgrey',
                alpha=0.7, label=r'$E^{\rm max}_{\rm iso}$ of Atteia+17')
for i, mod in enumerate(model_names_ks):
    ax.hist(np.log10(dfs[mod].properties['Eiso']), bins=np.linspace(48, 55, 50), histtype='step', linewidth=3,
            alpha=0.8, density=True, label=mod.replace('_',' '), color=colors[i])


ax.autoscale()
ax.legend(loc=0)
ax.set_ylabel(r'Normalized density')
ax.set_xlabel(r'log $E_{\rm iso}$ [erg]')
# fig.savefig('/Users/palmerio/Science_projects/Papers/LGRB_population_model/plots/Eiso_distr.pdf',
#             bbox_inches='tight')

# %%
for i,mod in enumerate(model_names_ks):
    cond = dfs[mod].properties['pht_pflx_BAT'] >= 2.6
    fig, axes = pf.cool_hist2d(np.log10(dfs[mod].properties['Eiso'].to_numpy()), np.log10(dfs[mod].properties['Ep'].to_numpy()),
               mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False, cb=False,
               plot_left_hist=True, plot_top_hist=True,
               left_hist_kwargs={'label': None,
                                     'bins':np.linspace(1,4,31),
                                     'edgecolor':'gray',
                                     'linewidth':3,
                                     'zorder':5,
                                     'alpha':0.9,
                                     'histtype':'step'},
                top_hist_kwargs={'label': None,
                                    'bins': np.linspace(49,55,31),
                                    'edgecolor': 'gray',
                                    'linewidth':3,
                                    'zorder':5,
                                    'alpha':0.9,
                                    'histtype':'step'},
               hist2d_kwargs={'color':'gray', 'bins':30,
                              'contour_kwargs':{'linewidths':1.5, 'zorder':2},
                              'plot_datapoints':False, 
                              'plot_density':False, 
                              'plot_contours':True,
                              'fill_contours':False})
    pf.cool_hist2d(np.log10(dfs[mod].properties[cond]['Eiso'].to_numpy()), np.log10(dfs[mod].properties[cond]['Ep'].to_numpy()),
                   mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False, fig=fig, cb=False,
                   left_hist_kwargs={'label': None,
                                     'bins':np.linspace(1,4,31),
                                     'edgecolor':colors[i],
                                     'linewidth':3,
                                     'zorder':5,
                                     'alpha':0.9,
                                     'histtype':'step'},
                   top_hist_kwargs={'label': None,
                                    'bins': np.linspace(49,55,31),
                                    'edgecolor': colors[i],
                                    'linewidth':3,
                                    'zorder':5,
                                    'alpha':0.9,
                                    'histtype':'step'},
                   hist2d_kwargs={'color':colors[i], 
                                  'contour_kwargs':{'linewidths':1.5},
                                  'plot_datapoints':False, 
                                  'plot_density':False, 
                                  'plot_contours':True,
                                  'fill_contours':True})
    axes['left'].set_ylabel(r'log Peak Energy $\rm{[keV]}$')
    axes['center'].set_xlabel(r'log $E_{\rm iso}~\rm{[erg]}$')
    axes['center'].set_xlim(49.3,54.8)
    axes['center'].set_ylim(1.3, 3.9)
    axes['center'].tick_params(labelsize=23)
    axes['left'].tick_params(labelsize=23)
# Out:
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# This is to check if using the 'GOOD' criteria defined by Gruber+14 and Bhat+16 as low relative errors on Ep and on
# the amplitude of the Band spectrum fit introduces a bias against low or high Ep.
# Conclusion : YES the relative error on the amplitude is higher at low Ep than at high Ep

def calc_rel_errors_GBM_band(df_obs):
    # Calculate relative errors on Band parameters for later filtering
    keys =  ['pflx_band_epeak_pos_err','pflx_band_epeak', 'pflx_band_ampl_pos_err', 'pflx_band_ampl']
    for k in keys:
        df_obs[k] = pd.to_numeric(df_obs[k], errors='coerce')
    df_obs['pflx_band_epeak_rel_err'] = df_obs['pflx_band_epeak_pos_err']/df_obs['pflx_band_epeak']
    df_obs['pflx_band_ampl_rel_err'] = df_obs['pflx_band_ampl_pos_err']/df_obs['pflx_band_ampl']
    return df_obs

# Read the GBM data
df_obs = pd.read_csv('../catalogs/GBM_cat/fermi_GBM_cat_total.dat', sep='|', header=2, low_memory=False)
df_obs.rename(columns=lambda x:x.strip(), inplace=True)

# Filter out short and incomplete (low peak flux) GRBs
df_obs = msc.filter_df(df_obs, 't90', lim_min=2, errors='coerce')
df_obs = msc.filter_df(df_obs, 'pflx_band_phtfluxb', lim_min=0.9, errors='coerce')
# for i,col in enumerate(df_obs.columns):
#     print(i,col)
df_obs = calc_rel_errors_GBM_band(df_obs)
df_obs['pflx_band_ampl_rel_err'].replace(0,1e-3, inplace=True)

# Plot the Ep relative error vs Ep
fig, axes = pf.cool_hist2d(np.log10(df_obs['pflx_band_epeak']),
                           np.log10(df_obs['pflx_band_epeak_rel_err']),
                           c=np.log10(df_obs['pflx_band_phtfluxb']))
axes['center'].axhline(np.log10(0.4), color='C3')
axes['center'].set_xlabel('log Peak Energy (keV)')
axes['left'].set_ylabel('log Peak Energy relative error')

# Plot the Band amplitude relative error vs Ep
fig, axes = pf.cool_hist2d(np.log10(df_obs['pflx_band_epeak']),
                           np.log10(df_obs['pflx_band_ampl_rel_err']),
                           c=np.log10(df_obs['pflx_band_phtfluxb']))
axes['center'].axhline(np.log10(0.4), color='C3')
axes['center'].set_xlabel('log Peak Energy (keV)')
axes['left'].set_ylabel('log Amplitude relative error')



# Look at the GBM Ep distribution for different criteria :
# - all GRBs that are long and complete
# - when BAND is best fit model
# - all GRBs satisfying 'GOOD' criteria of Gruber+14 and Bhat+16 
# (i.e. with low errors on alpha and beta and low relative errors on Ep and the amplitude of the Band fit)
bins = np.linspace(0,4.5, 30)
fig, ax = plt.subplots(figsize=(10,8))
pf.plot_obs_property('../catalogs/GBM_cat/fermi_GBM_cat_total.dat',
                  key='pflx_band_epeak',
                  func=[msc.filter_df, msc.filter_df],
                  func_args=[{'filtering_key':'t90', 'lim_min':2, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_phtfluxb', 'lim_min':0.9, 'errors':'coerce'}],
                  log=True, verbose=True, kde=False,
                  bins=bins,
                  ax=ax, density=True, label='GBM constraint', alpha=0.8,
                  color='lightgray', errors='coerce')
pf.plot_obs_property('../catalogs/GBM_cat/fermi_GBM_cat_total.dat',
                  key='pflx_band_epeak',
                  func=[msc.filter_df for i in range(3)],
                  func_args=[{'filtering_key':'t90', 'lim_min':2, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_phtfluxb', 'lim_min':0.9, 'errors':'coerce'},
                             {'filtering_key':'pflx_best_fitting_model', 'equal':'pflx_band', 'string':True}],
                  log=True, verbose=True, kde=False,
                  bins=bins,
                  ax=ax, density=True, label='Band best model', linewidth=3, histtype='step',
                  color='C1', errors='coerce')
func_list = [calc_rel_errors_GBM_band]
func_list += [msc.filter_df for i in range(7)]
pf.plot_obs_property('../catalogs/GBM_cat/fermi_GBM_cat_total.dat',
                  key='pflx_band_epeak',
                  func=func_list,
                  func_args=[{},
                             {'filtering_key':'t90', 'lim_min':2, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_phtfluxb', 'lim_min':0.9, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_alpha_pos_err', 'lim_max':0.4, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_beta_pos_err', 'lim_max':1.0, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_beta_pos_err', 'lim_max':1.0, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_epeak_rel_err', 'lim_max':0.4, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_ampl_rel_err', 'lim_max':0.4, 'errors':'coerce'}],
                  log=True, verbose=True, kde=False,
                  bins=bins,
                  ax=ax, density=True, label='Band GOOD', linewidth=3, histtype='step',
                  color='C2', errors='coerce')
ax.legend()
ax.set_xlabel('log Peak Energy (keV)')
ax.set_ylabel('PDF')

plt.show()
# Out:
# Sample size :1313
# Sample size :78
# Sample size :345

# %%
# Now look at Ep-L plane and Ep distributions of various observed samples to try to distinguish between
# Amati-like (intrinsic correlation) scenarios and LogNormal scenarios
bins = np.linspace(0,4.5, 30)
fig, axes = plt.subplots(2,2, figsize=(15,12), sharex='all', sharey='all')
ax = axes[0,0]
ax2 = axes[1,0]
ax3 = axes[0,1]
ax4 = axes[1,1]

# GBM bright
pf.plot_obs_property('../catalogs/GBM_cat/fermi_GBM_cat_total.dat',
                  key='pflx_band_epeak',
                  func=[msc.filter_df, msc.filter_df],
                  func_args=[{'filtering_key':'t90', 'lim_min':2, 'errors':'coerce'},
                             {'filtering_key':'pflx_band_phtfluxb', 'lim_min':0.9, 'errors':'coerce'}],
                  log=True, verbose=True, kde=True,
                  bins=bins,
                  ax=ax, density=True, label='GBM bright', alpha=0.8,
                  color='lightgray', errors='coerce')
for i,mod in enumerate(model_names_ks):
    cond = dfs[mod]['pdet_EpGBM'] == 1
    ax.hist(np.log10(dfs[mod][cond]['Epobs']), alpha=0.8, density=True,
            bins=bins, color=colors[i], histtype='step', linewidth=3, label=mod.replace('_',' '))

ax.set_ylabel(r'Normalized density')
ax.legend(loc='upper left')


# Observational constraint
pf.plot_EpGBM(fname=paths_to_dir['root']/'observational_constraints/EpGBM_for_plotting.txt',
              ax=ax, density=True, log=True,
              linewidth=3, color='k', fmt='.', capsize=3)


# Swift
pf.plot_obs_property('../catalogs/Swift_cat/Swift_cat_complete.txt',
                  key='bat_epeak',
                  func=[msc.filter_df, msc.filter_df],
                  func_args=[{'filtering_key':'bat_t90', 'lim_min':2, 'errors':'coerce'},
                             {'filtering_key':'bat_peakfluxp', 'lim_min':0.2, 'errors':'coerce'}],
                  log=True, verbose=True, kde=True,
                  bins=bins,
                  ax=ax2, density=True, label='Swift all', alpha=0.8,
                  color='lightgray', errors='coerce')
for i,mod in enumerate(model_names_ks):
    cond = dfs[mod]['pht_pflx_BAT'] >= 0.2
    ax2.hist(np.log10(dfs[mod][cond]['Epobs']), alpha=0.8, density=True,
            bins=bins, color=colors[i], histtype='step', linewidth=3, label=mod.replace('_',' '))


ax2.set_xlabel(r'log observed Peak Energy $\rm{[keV]}$')
ax2.set_ylabel(r'Normalized density')
ax2.legend(loc='upper left')

# BATSE bright
pf.plot_obs_property('../catalogs/BATSE_cat/BATSE_bright_cat.txt',
                  key='peak_energy',
                  func=msc.filter_df,
                  func_args={'filtering_key':'spectral_model', 'equal':'BAND', 'string':True},
                  log=True, verbose=True, kde=True,
                  bins=np.linspace(0,4.5, 30),
                  ax=ax3, density=True, label='BATSE bright', alpha=0.8,
                  color='lightgray', errors='coerce')

for i,mod in enumerate(model_names_ks):
    cond = dfs[mod]['pht_pflx_BATSE'] >= 3.0
    ax3.hist(np.log10(dfs[mod][cond]['Epobs']), alpha=0.8, density=True,
            bins=bins, color=colors[i], histtype='step', linewidth=3, label=mod.replace('_',' '))


ax3.legend()

# BATSE 20 - 2000 keV
pf.plot_obs_property('../catalogs/BATSE_cat/BATSE_cat_complete_5B.txt',
                  key='pflx_band_epeak',
                  func=msc.filter_df,
                  func_args={'filtering_key':'pflx_band_phtflux', 'lim_min':2.},
                  log=True, verbose=True, kde=True,
                  bins=np.linspace(0,4.5, 30),
                  ax=ax4, density=True, label='BATSE 5B', alpha=0.8,
                  color='lightgray', errors='coerce')

for i,mod in enumerate(model_names_ks):
    cond = dfs[mod]['pht_pflx_BATSE_5B'] >= 2.0
    ax4.hist(np.log10(dfs[mod][cond]['Epobs']), alpha=0.8, density=True,
            bins=bins, color=colors[i], histtype='step', linewidth=3, label=mod.replace('_',' '))


ax4.set_xlabel(r'log observed Peak Energy $\rm{[keV]}$')
ax4.legend()

fig.subplots_adjust(hspace=0, wspace=0)
plt.show()
# Out:
# Sample size :1313
# Sample size :132
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# Sample size :124
# Sample size :819

# %%
for i,mod in enumerate(model_names_ks):
    cond = dfs[mod].properties['pht_pflx_BAT'] >= 2.6
    fig, axes = pf.cool_hist2d(np.log10(dfs[mod].properties[cond]['L'].to_numpy()), np.log10(dfs[mod].properties[cond]['Ep'].to_numpy()),
                   mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False,
                   left_hist_kwargs={'label': None,
                                     'bins': np.linspace(0,4,30),
                                     'edgecolor':colors[i],
                                     'linewidth':3,
                                     'zorder':5,
                                     'alpha':0.9,
                                     'histtype':'step'},
                   top_hist_kwargs={'label': None,
                                    'bins': np.linspace(48,55,30),
                                    'edgecolor': colors[i],
                                    'linewidth':3,
                                    'zorder':5,
                                    'alpha':0.9,
                                    'histtype':'step'},
                   hist2d_kwargs={'color':colors[i], 
                                  'contour_kwargs':{'linewidths':1.5},
                                  'plot_datapoints':False, 
                                  'plot_density':False, 
                                  'plot_contours':True,
                                  'fill_contours':True})
    pf.plot_eBAT6_EpL(axes=axes, mini_cax=False)
# Out:
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:51: RuntimeWarning: invalid value encountered in log10
#   log_x[0] = np.log10(x[0])
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:52: RuntimeWarning: invalid value encountered in log10
#   log_x[1] = np.log10(x[0] + x[1]) - log_x[0]
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:53: RuntimeWarning: invalid value encountered in log10
#   log_x[2] = log_x[0] - np.log10(x[0] - x[2])
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:51: RuntimeWarning: invalid value encountered in log10
#   log_x[0] = np.log10(x[0])
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:52: RuntimeWarning: invalid value encountered in log10
#   log_x[1] = np.log10(x[0] + x[1]) - log_x[0]
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:53: RuntimeWarning: invalid value encountered in log10
#   log_x[2] = log_x[0] - np.log10(x[0] - x[2])
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:51: RuntimeWarning: invalid value encountered in log10
#   log_x[0] = np.log10(x[0])
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:52: RuntimeWarning: invalid value encountered in log10
#   log_x[1] = np.log10(x[0] + x[1]) - log_x[0]
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:53: RuntimeWarning: invalid value encountered in log10
#   log_x[2] = log_x[0] - np.log10(x[0] - x[2])
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:51: RuntimeWarning: invalid value encountered in log10
#   log_x[0] = np.log10(x[0])
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:52: RuntimeWarning: invalid value encountered in log10
#   log_x[1] = np.log10(x[0] + x[1]) - log_x[0]
# /Users/palmerio/Science_projects/GRB_population_model/src/miscellaneous.py:53: RuntimeWarning: invalid value encountered in log10
#   log_x[2] = log_x[0] - np.log10(x[0] - x[2])
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/seaborn/distributions.py:338: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set_xlim(0, auto=None)
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dfs[mod].columns
# Out:
# Index(['z', 'L', 'Ep', 't90obs', 'Cvar', 'alpha', 'beta', 'ktild', 'D_L',
#        'Epobs', 'Eiso', 't90', 'pht_pflx_BATSE', 'pht_pflx_BAT',
#        'pht_cts_ECLAIRs', 'erg_pflx_BATSE', 'erg_pflx_BAT', 'erg_cts_ECLAIRs',
#        'pht_flnc_BATSE', 'pht_flnc_BAT', 'pht_flnc_ECLAIRs', 'erg_flnc_BATSE',
#        'erg_flnc_BAT', 'erg_flnc_ECLAIRs', 'pdet_Stern', 'pdet_EpGBM',
#        'pdet_eBAT6', 'pdet_Swift', 'pdet_ECLAIRs_tot', 'pdet_ECLAIRs_pht_flnc',
#        'pdet_ECLAIRs_pht_cts', 'pdet_SHOALS', 'pht_pflx_GBM',
#        'pht_pflx_BATSE_5B', 'erg_pflx_GBM', 'erg_pflx_BATSE_5B',
#        'pht_flnc_GBM', 'pht_flnc_BATSE_5B', 'erg_flnc_GBM',
#        'erg_flnc_BATSE_5B', 'pdet_GBM_sample', 'pdet_BATSE_5B_sample'],
#       dtype='object')

# %%
# Now lets look at the predictions for SVOM in more detail

# for mod in model_names_ks:
# fig, ax = plt.subplots(figsize=(10,9))
# bins_t90 = np.linspace(-1,4,30)
# ax.hist(np.log10(dfs[mod]['t90']), bins=bins_t90, weights=dfs[mod]['pdet_ECLAIRs_tot'],
#         color='lightgray', label='ECLAIRs population')
# ax.hist(np.log10(dfs[mod]['t90']), bins=bins_t90, weights=dfs[mod]['pdet_ECLAIRs_pht_flnc'],
#         color='darkorange', label='Fluence', alpha=0.5)
# ax.hist(np.log10(dfs[mod]['t90']), bins=bins_t90, weights=dfs[mod]['pdet_ECLAIRs_pht_cts'],
#         color='purple', label='Peak flux', alpha=0.5)
# ax.legend()
fig, axes = pf.cool_hist2d(np.log10(dfs[mod].properties['pht_cts_ECLAIRs'].to_numpy()),
                           np.log10(dfs[mod].properties['t90'].to_numpy()),
                   mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False, cb=False,
                   left_hist_kwargs={'label': None,'weights':dfs[mod].properties['pdet_ECLAIRs_tot'],
                                     'bins': np.linspace(-1,4,30),
                                     'color':'lightgray',
                                     'zorder':5,
                                     'alpha':0.9},
                   top_hist_kwargs={'label': None,'weights':dfs[mod].properties['pdet_ECLAIRs_tot'],
                                    'bins': np.linspace(-3,6,35),
                                    'color':'lightgray',
                                    'zorder':5,
                                    'alpha':0.9},
                   hist2d_kwargs={'color':'k',
                                  'weights':dfs[mod].properties['pdet_ECLAIRs_tot'],
                                  'contour_kwargs':{'linewidths':1.5},
                                  'plot_datapoints':False, 
                                  'plot_density':False, 
                                  'plot_contours':True,
                                  'fill_contours':True})

pf.cool_hist2d(np.log10(dfs[mod].properties['pht_cts_ECLAIRs'].to_numpy()),
                           np.log10(dfs[mod].properties['t90'].to_numpy()),
               fig=fig,
                   mode='hist2d', figsize=(10,9), plot_left_kdeplot=False, plot_top_kdeplot=False, cb=False,
                   left_hist_kwargs={'label': None,
                                     'bins': np.linspace(-1,4,30),
                                     'edgecolor':'purple', 'linewidth':3,
                                     'weights':dfs[mod].properties['pdet_ECLAIRs_pht_cts'],
                                     'zorder':5,
                                     'alpha':0.9, 'histtype':'step'},
                   top_hist_kwargs={'label': None,
                                    'bins': np.linspace(-0.5,5,40),
                                    'edgecolor':'purple', 'linewidth':3,
                                    'weights':dfs[mod].properties['pdet_ECLAIRs_pht_cts'],
                                    'zorder':5,
                                    'alpha':0.9, 'histtype':'step'},
                   hist2d_kwargs={'color':'purple', 'alpha':0.3,
                                  'weights':dfs[mod].properties['pdet_ECLAIRs_pht_cts'],
                                  'contour_kwargs':{'linewidths':3},
                                  'plot_datapoints':False, 
                                  'plot_density':False, 
                                  'plot_contours':True,
                                  'fill_contours':False,'no_fill_contours':True})
axes['center'].set_xlim(1, 5)
axes['left'].set_ylabel('log T90')
axes['center'].set_xlabel('log ECLAIRs count rate [cts/s]')

plt.show()
# Out:
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# All the things below are tests that didn't pan out
# Since just the redshift distribution of SHOALS doesn't help to discriminate much, maybe the L-z plane will
mod = 'k0_LN_nF'
cond = (dfs[mod].properties['erg_flnc_BAT']>=1e-7)
pf.cool_hist2d(dfs[mod].properties[cond]['z'].to_numpy(),
               np.log10(dfs[mod].properties[cond]['L'].to_numpy()),
               mode='hist2d', cb=False)
fig = plt.gcf()
axes = fig.axes
axes[0].set_xlim(0,7)
plt.show()



mod = 'k2_LN_nF'
cond = (dfs[mod].properties['erg_flnc_BAT']>=1e-7)
pf.cool_hist2d(dfs[mod].properties[cond]['z'].to_numpy(),
               np.log10(dfs[mod].properties[cond]['L'].to_numpy()),
               mode='hist2d', cb=False)
fig = plt.gcf()
axes = fig.axes
axes[0].set_xlim(0,7)
plt.show()

frac = np.zeros((len(size), len(flnc_cuts)))
k=0
# for i, j in product(range(len(size)), range(len(flnc_cuts))):
i=-1
j=-1
log.info("{} %. Size, fluence cut = {} {}".format(100*k/(len(size)*len(flnc_cuts)), size[i], flnc_cuts[j]))
frac[i,j]= st.subsample_and_KS(np.log10(dfs['k0_A_nF'].properties[(dfs['k0_A_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])]),
                             np.log10(dfs['k2_A_nF'].properties[(dfs['k2_A_nF'].properties['erg_flnc_BAT']>=flnc_cuts[j])]),
                             key='pht_flnc_BAT',
                             precision=precision,
                             bins=np.linspace(-4,4,precision+1),
                             N_sub=size[i],
                             N_bs=100,
                             subsample2=False, show_plot=True)
log.info("Fraction of samples different at the 95% confidence level : {}".format(frac[i,j]))
k+=1
plt.gcf().axes[0].set_xlabel('log photon fluence [ph/cm$^2$]')

p_discr_L['A'] = frac

# Plot the photon fluence distribution expected for SHOALS in the case of k=0 and k=2 for LogNormal and Amati models
# Also compute the KS tests between these fluence distributions and the observed SHOALS fluence distribution
fig, ax = plt.subplots(figsize=(10,8))
df_obs = io.read_SHOALS_file()
colors = ['#225ea8', '#41b6c4', '#ae017e', '#f768a1']
for i,mod in enumerate(model_names_ks):
    print(f"################# {mod} #####################")
    pf.plot_SHOALS_distr(dfs[mod].properties,
                          key='S_BAT',
                          plot_obs=(i==0),
                          cumul=True,
                          fig=fig,
                          mod_color=colors[i],
                          mod_label=mod.replace('_',' '))
    D_stat, p_value = ks_2samp(dfs[mod].properties[dfs[mod].properties['pdet_SHOALS']==1]['pht_flnc_BAT'], df_obs['S_BAT'])
    print("D-stat, p_value = {:.3f}, {:.3f}".format(D_stat, p_value))

# Plot the photon fluence distribution expected for SHOALS in the case of k=0 and k=2 for LogNormal and Amati models
# Also compute the KS tests between these fluence distributions and the observed SHOALS fluence distribution
fig, ax = plt.subplots(figsize=(10,8))
df_obs = obs.read_SHOALS_file()
colors = ['#225ea8', '#41b6c4', '#ae017e', '#f768a1']
for i,mod in enumerate(model_names_ks):
    print(f"################# {mod} #####################")
    pf.plot_SHOALS_distr(dfs[mod].properties['pht_flnc_BAT'],
                          key='S_BAT',
                          plot_obs=False,
                          cumul=True,
                          fig=fig,
                          mod_color=colors[i],
                          mod_label=mod.replace('_',' '))
    D_stat, p_value = ks_2samp(dfs[mod].properties[dfs[mod].properties['pdet_SHOALS']==1]['pht_flnc_BAT'], df_obs['S_BAT'])
    print("D-stat, p_value = {:.3f}, {:.3f}".format(D_stat, p_value))

# Plot the luminosity distribution expected for SHOALS in the case of k=0 and k=2 for LogNormal and Amati models
fig, ax = plt.subplots(figsize=(10,8))
df_obs = io.read_SHOALS_file()
colors = ['#225ea8', '#41b6c4', '#ae017e', '#f768a1']
for i,mod in enumerate(model_names_ks):
    print(f"################# {mod} #####################")
    pf.plot_SHOALS_distr(np.log10(dfs[mod].properties[dfs[mod].properties['pdet_SHOALS']==1]['L']),
                          key='L',
                          plot_obs=False,
                          cumul=True,
                          fig=fig,
                          mod_color=colors[i],
                          mod_label=mod.replace('_',' '))
# Out:
# 16:31:42.189 [INFO] 0.0 %. Size, fluence cut = 1000 1e-07
# 16:31:44.457 [INFO] Subsampling done in 0.678 s
# 16:31:52.942 [INFO] KS calculations done in 8.484 s
# 16:31:58.554 [INFO] CDF calculation done in 5.611 s
# 16:31:58.633 [WARNING] No handles with labels found to put in legend.
# 16:31:58.641 [WARNING] No handles with labels found to put in legend.
# 16:31:58.694 [INFO] Fraction of samples different at the 95% confidence level : 0.49
# ################# k0_LN_nF #####################
# D-stat, p_value = 0.072, 0.610
# ################# k2_LN_nF #####################
# D-stat, p_value = 0.076, 0.541
# ################# k0_A_nF #####################
# D-stat, p_value = 0.066, 0.708
# ################# k2_A_nF #####################
# D-stat, p_value = 0.073, 0.581
# ################# k0_LN_nF #####################
# D-stat, p_value = 0.072, 0.610
# ################# k2_LN_nF #####################
# D-stat, p_value = 0.076, 0.541
# ################# k0_A_nF #####################
# D-stat, p_value = 0.066, 0.708
# ################# k2_A_nF #####################
# D-stat, p_value = 0.073, 0.581
# ################# k0_LN_nF #####################
# ################# k2_LN_nF #####################
# ################# k0_A_nF #####################
# ################# k2_A_nF #####################
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /Users/palmerio/miniconda3/envs/python3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
