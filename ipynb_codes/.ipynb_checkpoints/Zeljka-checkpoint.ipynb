# %%
import sys
src_dir = '/Users/palmerio/Science_projects/GRB_population_model/src/'
sys.path.insert(0, src_dir)

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
verbose = True
run_mode = 'debug'
from prototype_GRB_population import *
# Out:
# ln(o_i!) = 37471.04257552522 from Stern histogram
# ln(o_i!) = 4168.986506912058 from EpGBM histogram
# ln(o_i!) = 958.9913351276238 from eBAT6 histogram
# 17:22:39.147 [DEBUG] Root directory is /Users/palmerio/Science_projects/GRB_population_model
# 17:22:39.148 [DEBUG] Directory paths :
#     'root'    : /Users/palmerio/Science_projects/GRB_population_model
#     'obs'     : /Users/palmerio/Science_projects/GRB_population_model/observational_constraints
#     'init'    : /Users/palmerio/Science_projects/GRB_population_model/init
#     'output'  : /Users/palmerio/Science_projects/GRB_population_model/model_outputs
#     'data'    : /Users/palmerio/Science_projects/GRB_population_model/data
#     'cosmo'   : /Users/palmerio/Science_projects/GRB_population_model/data/cosmology
#     'ECLAIRs' : /Users/palmerio/Science_projects/GRB_population_model/data/ECLAIRs
# 17:22:39.148 [DEBUG] File paths :
#     'config'  : /Users/palmerio/Science_projects/GRB_population_model/init/config.yml
#     'param'   : /Users/palmerio/Science_projects/GRB_population_model/init/parameters.yml
#     'instrum' : /Users/palmerio/Science_projects/GRB_population_model/init/instruments.yml
#     'sample'  : /Users/palmerio/Science_projects/GRB_population_model/init/samples.yml
# 17:22:39.165 [DEBUG] Input configuration:
# Nb_GRBs: 1e5
# likelihood:
#     epsilon: 0.001
# output_dir: Zeljka_w_Cvar
# samples:
# - Stern
# - GBM_sample
# - Swift
# save_all_GRBs: false
#
# 17:22:39.169 [DEBUG] Input parameters:
# Cvar_distribution:
#     correl_slope: 0.413
#     mu: 0.04
#     sigma: 0.22
# luminosity_function:
#     k_evol: 1.0
#     logLbreak: 52.56
#     logLmax: 53.0
#     logLmin: 49.6989700043
#     model: ES
#     slope: 1.41
# peak_energy_distribution:
#     Ep0: 690
#     alpha_amati: 0.3
#     model: LN
#     sigmaEp: 0.45
# redshift_distribution:
#     a: 0.94
#     b: -0.52
#     model: BExp
#     zeta: null
#     zm: 2.18
#     zmax: 20
# spectral_shape:
#     alpha: 0.6
#     beta: 2.5
#     model: GBM_Band
# t90obs_distribution:
#     mu: 1.45
#     sigma: 0.47
#
# 17:22:39.178 [DEBUG] ==============================================
# 17:22:39.178 [DEBUG] ===           ECLAIRs instrument           ===
# 17:22:39.179 [DEBUG] ==============================================
# 17:22:39.180 [DEBUG] ECLAIRs energy channel: 4.0 to 150.0 keV
# 17:22:39.181 [DEBUG] ECLAIRs detection level: 6.5 sigmas
# 17:22:39.218 [DEBUG] Effective area: from 1.013650e+02 cm2 at 4.00 keV
# 17:22:39.219 [DEBUG] Effective area: to   1.811580e+02 cm2 at 250.00 keV
# 17:22:39.220 [DEBUG] Background: from 2.819620e+02 cts/s/keV at 4.00 keV
# 17:22:39.220 [DEBUG] Background: to   8.730200e-02 cts/s/keV at 250.00 keV
# 17:22:39.221 [DEBUG] ECLAIRs background: 3.098396e+03 cts/s from 4.00 keV to 150.00 keV
# 17:22:39.222 [DEBUG] ==============================================
# 17:22:39.223 [INFO] Number of GRBs simulated: 1.00e+05
# 17:22:39.223 [INFO] Including samples: ['Stern', 'GBM_sample', 'Swift']
# 17:22:39.225 [DEBUG] Including samples:
# GBM_sample:
#     instrument: GBM
#     pflx_min: 3.0
# Stern:
#     instrument: BATSE
#     pflx_min: 0.066825
# Swift:
#     instrument: BAT
#     pflx_min: 0.2
#
# 17:22:39.226 [INFO] Including instruments: ['BATSE', 'GBM', 'BAT']
# 17:22:39.231 [DEBUG] Including instruments:
# BAT:
#     Emax: 150.0
#     Emin: 15.0
# BATSE:
#     Emax: 300.0
#     Emin: 50.0
# GBM:
#     Emax: 1000.0
#     Emin: 10.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import logging
import time
import sys
import pandas as pd
import physics as ph
import io_grb_pop as io
import miscelaneous as msc
import observational_constraints as obs
from GRB_population import GRBPopulation
from cosmology import init_cosmology
from ECLAIRs import init_ECLAIRs
from stats import MonteCarlo_routine

############
load_files = True
############

# %%
io.create_output_dir(paths_to_dir, dir_name=config['output_dir'],
                             run_mode=run_mode)
if not load_files:
    np.random.seed(0)
    tstart = time.time()
    GRB_population = GRBPopulation(Nb_GRBs, output_dir=paths_to_dir['output'])
    GRB_prop = GRB_population.draw_GRB_properties(cosmo=cosmo, params=params)

    ph.calc_peak_photon_flux(GRB_prop, incl_instruments, ECLAIRs_prop)
    ph.calc_peak_energy_flux(GRB_prop, incl_instruments, ECLAIRs_prop)
    ph.calc_photon_fluence(GRB_prop, incl_instruments)
    ph.calc_energy_fluence(GRB_prop, incl_instruments)
    ph.calc_det_prob(GRB_prop, incl_samples, **ECLAIRs_prop)

    df = pd.DataFrame(GRB_prop)
# Out:
# 17:22:49.770 [INFO] Output directory updated to /Users/palmerio/Science_projects/GRB_population_model/model_outputs/191201_Zeljka_w_Cvar
# 17:22:49.889 [DEBUG] Starting calculations of peak photon fluxes...
# 17:22:49.890 [DEBUG] For BATSE instrument [50.0, 300.0 keV]:
# 17:22:50.708 [DEBUG] Done in 0.818 s
# 17:22:50.709 [DEBUG] For GBM instrument [10.0, 1000.0 keV]:
# 17:22:51.475 [DEBUG] Done in 0.766 s
# 17:22:51.476 [DEBUG] For BAT instrument [15.0, 150.0 keV]:
# 17:22:52.239 [DEBUG] Done in 0.763 s
# 17:22:52.240 [DEBUG] Starting calculations of peak energy fluxes...
# 17:22:52.241 [DEBUG] For BATSE instrument [50.0, 300.0 keV]:
# 17:22:53.005 [DEBUG] Done in 0.764 s
# 17:22:53.006 [DEBUG] For GBM instrument [10.0, 1000.0 keV]:
# 17:22:53.762 [DEBUG] Done in 0.756 s
# 17:22:53.762 [DEBUG] For BAT instrument [15.0, 150.0 keV]:
# 17:22:54.508 [DEBUG] Done in 0.745 s
# 17:22:54.508 [DEBUG] Starting calculations of photon fluences...
# 17:22:54.509 [DEBUG] Starting calculations of energy fluences...
# 17:22:54.511 [DEBUG] Starting calculations of detection probability...
# 17:22:54.512 [DEBUG] Stern sample:
# 17:22:54.513 [DEBUG] Done in 0.001 s
# 17:22:54.514 [DEBUG] GBM_sample sample:
# 17:22:54.515 [DEBUG] Done in 0.001 s
# 17:22:54.516 [DEBUG] Swift sample:
# 17:22:54.518 [DEBUG] Done in 0.002 s

# %%
df
# Out:
#        Nb_GRBs      z             L           Ep      t90obs      Cvar  \
# 0       100000  2.488  8.709831e+50  1075.674179   75.525730  0.152786
# 1       100000  3.057  1.396389e+52   164.092569   25.145532  0.427214
# 2       100000  2.645  7.907064e+50   220.058949    8.398272  0.350519
# 3       100000  2.477  2.190679e+50   127.161189   61.179481  0.176116
# 4       100000  2.185  7.639785e+50   116.639918   61.894119  0.239741
# ...        ...    ...           ...          ...         ...       ...
# 99995   100000  3.104  5.495233e+50  1270.212849  200.816376  0.082878
# 99996   100000  2.380  3.701583e+50  1351.154396   15.632354  0.431893
# 99997   100000  3.562  3.847032e+50  8231.678053    9.044525  0.176714
# 99998   100000  2.494  3.712766e+50   842.340649   25.825846  0.133955
# 99999   100000  1.679  4.516803e+51  1299.575392   12.254894  0.537510
#
#           alpha     beta     ktild           D_L  ...  erg_pflx_BAT  \
# 0      1.160800  3.07715  0.699629  20580.690742  ...  5.430342e-09
# 1     -0.237003  2.18647  1.457056  26443.739383  ...  5.023065e-08
# 2      0.433020  2.89143  1.818182  22177.953974  ...  8.889956e-09
# 3      0.705592  2.49261  1.001099  20469.423445  ...  2.250904e-09
# 4      0.587377  4.04809  1.775865  17549.217070  ...  1.470773e-08
# ...         ...      ...       ...           ...  ...           ...
# 99995  0.497795  2.51747  1.321066  26936.575471  ...  1.177270e-09
# 99996  0.394991  3.07715  2.027200  19492.065259  ...  1.438444e-09
# 99997  0.770485  2.25587  0.621508  31797.513066  ...  6.696764e-11
# 99998  0.482071  2.61339  1.466183  20641.418411  ...  1.900112e-09
# 99999  0.945143  2.50134  0.744709  12668.805054  ...  3.672607e-08
#
#        pht_flnc_BATSE  pht_flnc_GBM  pht_flnc_BAT  erg_flnc_BATSE  \
# 0            0.413824      1.136893      0.760542    8.075868e-08
# 1            2.503725     10.719531      8.135177    4.115337e-07
# 2            0.123860      0.486666      0.380121    1.816086e-08
# 3            0.093772      0.580397      0.408895    1.433157e-08
# 4            0.678543      5.511646      3.986445    8.285718e-08
# ...               ...           ...           ...             ...
# 99995        0.161237      0.308662      0.192129    3.455968e-08
# 99996        0.087275      0.161783      0.090105    1.971935e-08
# 99997        0.000963      0.002272      0.001057    2.225303e-10
# 99998        0.050979      0.098713      0.066173    1.046115e-08
# 99999        1.835067      4.301853      2.651966    3.854477e-07
#
#        erg_flnc_GBM  erg_flnc_BAT  pdet_Stern  pdet_GBM_sample  pdet_Swift
# 0      1.631898e-07  6.266236e-08         0.0              0.0         0.0
# 1      9.291706e-07  5.396034e-07         1.0              0.0         1.0
# 2      3.550783e-08  2.616987e-08         0.0              0.0         0.0
# 3      3.591561e-08  2.425279e-08         0.0              0.0         0.0
# 4      2.579625e-07  2.182413e-07         0.0              0.0         1.0
# ...             ...           ...         ...              ...         ...
# 99995  6.947584e-08  1.959355e-08         0.0              0.0         0.0
# 99996  4.434977e-08  9.711661e-09         0.0              0.0         0.0
# 99997  8.650641e-10  1.070339e-10         0.0              0.0         0.0
# 99998  1.885634e-08  6.573425e-09         0.0              0.0         0.0
# 99999  9.128069e-07  2.419193e-07         1.0              0.0         1.0
#
# [100000 rows x 28 columns]

# %%
col_to_write = ['z', 'alpha', 'beta', 'Epobs', 'L', 'Eiso', 't90', 'Cvar',
                'pht_pflx_BATSE','erg_pflx_BATSE','pht_flnc_BATSE','erg_flnc_BATSE',
                'pht_pflx_BAT','erg_pflx_BAT','pht_flnc_BAT','erg_flnc_BAT',
                'pht_pflx_GBM','erg_pflx_GBM','pht_flnc_GBM','erg_flnc_GBM']

if not load_files:
    df.to_csv(paths_to_dir['output']/'lognormal_Ep.dat',sep='\t', index=False, columns=col_to_write)
